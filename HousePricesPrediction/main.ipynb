# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
train_data = pd.read_csv("data/train.csv")
test_data = pd.read_csv("data/train.csv")

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd        NaN
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng        NaN
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
train_data[train_data['SalePrice'] == train_data['SalePrice'].max()]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691  692          60       RL        104.0    21535   Pave   NaN      IR1
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 691         Lvl    AllPub    Corner       Gtl      NoRidge       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 691       Norm     1Fam     2Story           10            6       1994
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 691          1995     Gable  WdShngl     HdBoard     HdBoard    BrkFace
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 691      1170.0        Ex        TA      PConc       Ex       TA           Gd
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 691          GLQ        1455          Unf           0        989         2444
#
#     Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 691    GasA        Ex          Y      SBrkr      2444      1872             0
#
#      GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 691       4316             0             1         3         1             4
#
#      KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 691             1          Ex            10        Typ           2
#
#     FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 691          Ex     Attchd       1994.0          Fin           3         832
#
#     GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 691         TA         TA          Y         382           50              0
#
#      3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  \
# 691          0            0         0    NaN   NaN         NaN        0
#
#      MoSold  YrSold SaleType SaleCondition  SalePrice
# 691       1    2007       WD        Normal     755000

# %%
train_data[train_data['SalePrice'] == train_data['SalePrice'].min()]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 495  496          30  C (all)         60.0     7879   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 495         Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 495       Norm     1Fam     1Story            4            5       1920
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 495          1950     Gable  CompShg     Wd Sdng     Wd Sdng        NaN
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 495         0.0        TA        TA     CBlock       TA       TA           No
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 495          Rec         495          Unf           0        225          720
#
#     Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 495    GasA        TA          N      FuseA       720         0             0
#
#      GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 495        720             0             0         1         0             2
#
#      KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 495             1          TA             4        Typ           0
#
#     FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 495         NaN        NaN          NaN          NaN           0           0
#
#     GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 495        NaN        NaN          N           0          523            115
#
#      3SsnPorch  ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  \
# 495          0            0         0    NaN  GdWo         NaN        0
#
#      MoSold  YrSold SaleType SaleCondition  SalePrice
# 495      11    2009       WD       Abnorml      34900

# %%
import matplotlib.pyplot as plt

plt.hist(train_data['SalePrice'], bins=30)
plt.xlabel('SalePrice')
plt.ylabel('Records')
plt.title('SalePrice Distribution')
plt.show()

# %% [markdown]
# ### Gathering Evidence For The Features That We Considered As High Potential

# %%
selected_columns = [
    "SalePrice",
    "MSSubClass",
    "MSZoning",
    "LotFrontage",
    "LotArea",
    "Neighborhood",
    "HouseStyle",
    "OverallQual",
    "OverallCond",
    "MasVnrType",
    "MasVnrArea",
    "ExterQual",
    "Foundation",
    "BsmtQual",
    "BsmtFinType1",
    "BsmtFinSF1",
    "1stFlrSF",
    "2ndFlrSF",
    "GrLivArea",
    "FullBath",
    "HalfBath",
    "KitchenQual",
    "TotRmsAbvGrd",
    "GarageType",
    "GarageFinish",
    "GarageCars",
    "GarageArea",
]

train_selected = train_data[selected_columns]

# %%
pd.concat([
    train_selected.head(5),
    train_selected.tail(5),
    train_selected.loc[
        [
            train_selected['SalePrice'].idxmax(),
            train_selected['SalePrice'].idxmin()
        ]
    ]
]).sort_values(by='SalePrice', ascending=False)
# Out:
#       SalePrice  MSSubClass MSZoning  LotFrontage  LotArea Neighborhood  \
# 691      755000          60       RL        104.0    21535      NoRidge
# 1457     266500          70       RL         66.0     9042      Crawfor
# 4        250000          60       RL         84.0    14260      NoRidge
# 2        223500          60       RL         68.0    11250      CollgCr
# 1456     210000          20       RL         85.0    13175       NWAmes
# 0        208500          60       RL         65.0     8450      CollgCr
# 1        181500          20       RL         80.0     9600      Veenker
# 1455     175000          60       RL         62.0     7917      Gilbert
# 1459     147500          20       RL         75.0     9937      Edwards
# 1458     142125          20       RL         68.0     9717        NAmes
# 3        140000          70       RL         60.0     9550      Crawfor
# 495       34900          30  C (all)         60.0     7879       IDOTRR
#
#      HouseStyle  OverallQual  OverallCond MasVnrType  MasVnrArea ExterQual  \
# 691      2Story           10            6    BrkFace      1170.0        Ex
# 1457     2Story            7            9        NaN         0.0        Ex
# 4        2Story            8            5    BrkFace       350.0        Gd
# 2        2Story            7            5    BrkFace       162.0        Gd
# 1456     1Story            6            6      Stone       119.0        TA
# 0        2Story            7            5    BrkFace       196.0        Gd
# 1        1Story            6            8        NaN         0.0        TA
# 1455     2Story            6            5        NaN         0.0        TA
# 1459     1Story            5            6        NaN         0.0        Gd
# 1458     1Story            5            6        NaN         0.0        TA
# 3        2Story            7            5        NaN         0.0        TA
# 495      1Story            4            5        NaN         0.0        TA
#
#      Foundation BsmtQual BsmtFinType1  BsmtFinSF1  1stFlrSF  2ndFlrSF  \
# 691       PConc       Ex          GLQ        1455      2444      1872
# 1457      Stone       TA          GLQ         275      1188      1152
# 4         PConc       Gd          GLQ         655      1145      1053
# 2         PConc       Gd          GLQ         486       920       866
# 1456     CBlock       Gd          ALQ         790      2073         0
# 0         PConc       Gd          GLQ         706       856       854
# 1        CBlock       Gd          ALQ         978      1262         0
# 1455      PConc       Gd          Unf           0       953       694
# 1459     CBlock       TA          BLQ         830      1256         0
# 1458     CBlock       TA          GLQ          49      1078         0
# 3        BrkTil       TA          ALQ         216       961       756
# 495      CBlock       TA          Rec         495       720         0
#
#       GrLivArea  FullBath  HalfBath KitchenQual  TotRmsAbvGrd GarageType  \
# 691        4316         3         1          Ex            10     Attchd
# 1457       2340         2         0          Gd             9     Attchd
# 4          2198         2         1          Gd             9     Attchd
# 2          1786         2         1          Gd             6     Attchd
# 1456       2073         2         0          TA             7     Attchd
# 0          1710         2         1          Gd             8     Attchd
# 1          1262         2         0          TA             6     Attchd
# 1455       1647         2         1          TA             7     Attchd
# 1459       1256         1         1          TA             6     Attchd
# 1458       1078         1         0          Gd             5     Attchd
# 3          1717         1         0          Gd             7     Detchd
# 495         720         1         0          TA             4        NaN
#
#      GarageFinish  GarageCars  GarageArea
# 691           Fin           3         832
# 1457          RFn           1         252
# 4             RFn           3         836
# 2             RFn           2         608
# 1456          Unf           2         500
# 0             RFn           2         548
# 1             RFn           2         460
# 1455          RFn           2         460
# 1459          Fin           1         276
# 1458          Unf           1         240
# 3             Unf           3         642
# 495           NaN           0           0

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.boxplot(
    [train_selected[train_selected['MSSubClass'] == cls]['SalePrice']
     for cls in sorted(train_selected['MSSubClass'].unique())],
    tick_labels=sorted(train_selected['MSSubClass'].unique())
)

plt.xlabel('MSSubClass')
plt.ylabel('SalePrice')
plt.title('MSSubClass vs SalePrice')
plt.xticks(rotation=45)
plt.show()

# %%
train_selected.groupby('MSZoning').size()
# Out:
# MSZoning
# C (all)      10
# FV           65
# RH           16
# RL         1151
# RM          218
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.boxplot(
    [train_selected[train_selected['MSZoning'] == cls]['SalePrice']
     for cls in sorted(train_selected['MSZoning'].unique())],
    tick_labels=sorted(train_selected['MSZoning'].unique())
)

plt.xlabel('MSZoning')
plt.ylabel('SalePrice')
plt.title('MSZoning vs SalePrice')
plt.xticks(rotation=45)
plt.show()

# %%
train_selected.loc[
    train_selected['MSZoning'] == 'C (all)',
    'SalePrice'
]
# Out:
# 30       40000
# 88       85000
# 93      133900
# 495      34900
# 557     108000
# 711     102776
# 812      55993
# 916      35311
# 1061     81000
# 1279     68400
# Name: SalePrice, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.boxplot(
    [train_selected[train_selected['Neighborhood'] == cls]['SalePrice']
     for cls in sorted(train_selected['Neighborhood'].unique())],
    tick_labels=sorted(train_selected['Neighborhood'].unique())
)

plt.xlabel('Neighborhood')
plt.ylabel('SalePrice')
plt.title('Neighborhood vs SalePrice')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.boxplot(
    [train_selected[train_selected['HouseStyle'] == cls]['SalePrice']
     for cls in sorted(train_selected['HouseStyle'].unique())],
    tick_labels=sorted(train_selected['HouseStyle'].unique())
)

plt.xlabel('HouseStyle')
plt.ylabel('SalePrice')
plt.title('HouseStyle vs SalePrice')
plt.xticks(rotation=45)
plt.show()

# %%
train_selected['MasVnrType'].isna().sum()
# Out:
# np.int64(872)

# %%
train_selected['MasVnrType'].value_counts()
# Out:
# MasVnrType
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.boxplot(
    [train_selected[train_selected['Foundation'] == cls]['SalePrice']
     for cls in sorted(train_selected['Foundation'].unique())],
    tick_labels=sorted(train_selected['Foundation'].unique())
)

plt.xlabel('Foundation')
plt.ylabel('SalePrice')
plt.title('Foundation vs SalePrice')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Implementing First Model On The Feature we consider to be baselines
# ### Features:
# #### Causes: OverallQual, ExterQual, Foundation, BsmtQual, BsmtCond, BsmtFinType1, GrLivArea, FullBath, KitchenQual, GarageArea
# #### Proxies: MSZoning, LotArea, Neighborhood, HouseStyle

# %%
selected_columns = [
    "SalePrice",
    "MSZoning",
    "LotArea",
    "Neighborhood",
    "HouseStyle",
    "OverallQual",
    "ExterQual",
    "Foundation",
    "BsmtQual",
    "BsmtCond",
    "BsmtFinType1",
    "GrLivArea",
    "FullBath",
    "KitchenQual",
    "GarageArea",
]

train_hp = train_data[selected_columns]

# %%
train_hp.isna().sum()
# Out:
# SalePrice        0
# MSZoning         0
# LotArea          0
# Neighborhood     0
# HouseStyle       0
# OverallQual      0
# ExterQual        0
# Foundation       0
# BsmtQual        37
# BsmtCond        37
# BsmtFinType1    37
# GrLivArea        0
# FullBath         0
# KitchenQual      0
# GarageArea       0
# dtype: int64

# %%
train_hp.shape[0]
# Out:
# 1460

# %%
cols = ['BsmtQual', 'BsmtCond', 'BsmtFinType1']

train_hp[train_hp[cols].isna().any(axis=1)]
# Out:
#       SalePrice MSZoning  LotArea Neighborhood HouseStyle  OverallQual  \
# 17        90000       RL    10791       Sawyer     1Story            4
# 39        82000       RL     6040      Edwards     1Story            4
# 90       109900       RL     7200        NAmes     1Story            4
# 102      118964       RL     7018      SawyerW     1Story            5
# 156      109500       RL     7200        NAmes     1Story            5
# 182      120000       RL     9060      Edwards     1Story            5
# 259       97000       RM    12702      OldTown     1Story            5
# 342       87500       RL     8544        NAmes     1Story            3
# 362      198500       RL     7301      Edwards     SFoyer            7
# 371      134432       RL    17120      ClearCr     1.5Fin            4
# 392      106500       RL     8339        NAmes     1Story            5
# 520      106250       RL    10800      OldTown     2Story            4
# 532      107500       RL     7200        NAmes     1Story            5
# 533       39300       RL     5000      BrkSide     1Story            1
# 553      108000       RL     8777      Edwards     1Story            4
# 646       98300       RL     7200        NAmes     1Story            5
# 705       55000       RM     5600       IDOTRR     2Story            4
# 736       93500       RL     8544        NAmes     1Story            3
# 749       98000       RL     8405      Edwards     1.5Fin            4
# 778      144000       RH     8400      SawyerW     1Story            5
# 868      169000       RL    14762      Gilbert     2Story            5
# 894      118858       RL     7018      SawyerW     1Story            5
# 897      142953       RL     7018      SawyerW     2Story            5
# 984      126000       RL    10125      Mitchel     1.5Fin            5
# 1000      82000       RL    10206      Edwards     1Story            3
# 1011     100000       RL     9825      Edwards     1Story            5
# 1035      84000       RL    11500      Edwards     1Story            4
# 1045     139600       RL    13680      Edwards     1Story            3
# 1048     115000       RL    21750      Mitchel     1Story            5
# 1049      84900       RL    11100      Edwards     1Story            4
# 1090      92900       RL     8544        NAmes     1Story            3
# 1179      93000       RL     8335      Edwards     1Story            5
# 1216     112000       RM     8930       Sawyer     1.5Fin            6
# 1218      80500       RM     6240      BrkSide     1.5Fin            4
# 1232     101800       RL     9842        NAmes     1Story            4
# 1321      72500       RL     6627      BrkSide     1Story            3
# 1412      90000       RL     7200        NAmes     1Story            4
#
#      ExterQual Foundation BsmtQual BsmtCond BsmtFinType1  GrLivArea  FullBath  \
# 17          TA       Slab      NaN      NaN          NaN       1296         2
# 39          TA      PConc      NaN      NaN          NaN       1152         2
# 90          TA       Slab      NaN      NaN          NaN       1040         1
# 102         TA       Slab      NaN      NaN          NaN       1535         2
# 156         TA     CBlock      NaN      NaN          NaN       1040         1
# 182         TA      PConc      NaN      NaN          NaN       1340         1
# 259         TA      PConc      NaN      NaN          NaN        882         1
# 342         TA       Slab      NaN      NaN          NaN       1040         2
# 362         Gd       Slab      NaN      NaN          NaN       1922         3
# 371         TA     CBlock      NaN      NaN          NaN       1588         2
# 392         TA       Slab      NaN      NaN          NaN        882         1
# 520         TA     BrkTil      NaN      NaN          NaN       1294         2
# 532         TA       Slab      NaN      NaN          NaN        827         1
# 533         Fa       Slab      NaN      NaN          NaN        334         1
# 553         TA     CBlock      NaN      NaN          NaN       1126         2
# 646         TA     CBlock      NaN      NaN          NaN       1048         1
# 705         Fa       Slab      NaN      NaN          NaN       1092         2
# 736         TA     CBlock      NaN      NaN          NaN       1040         2
# 749         TA       Slab      NaN      NaN          NaN       1529         2
# 778         TA       Slab      NaN      NaN          NaN       2020         2
# 868         TA       Slab      NaN      NaN          NaN       2320         2
# 894         TA       Slab      NaN      NaN          NaN       1535         2
# 897         TA       Slab      NaN      NaN          NaN       2240         2
# 984         TA     CBlock      NaN      NaN          NaN       1734         2
# 1000        TA       Slab      NaN      NaN          NaN        944         1
# 1011        TA     CBlock      NaN      NaN          NaN       1664         2
# 1035        TA       Slab      NaN      NaN          NaN        845         1
# 1045        TA       Slab      NaN      NaN          NaN       1733         2
# 1048        TA       Slab      NaN      NaN          NaN       1771         1
# 1049        TA     CBlock      NaN      NaN          NaN        930         1
# 1090        TA       Slab      NaN      NaN          NaN       1040         2
# 1179        TA       Slab      NaN      NaN          NaN       1124         1
# 1216        TA       Slab      NaN      NaN          NaN       1902         2
# 1218        TA       Slab      NaN      NaN          NaN        912         1
# 1232        TA       Slab      NaN      NaN          NaN       1224         2
# 1321        TA     CBlock      NaN      NaN          NaN        720         1
# 1412        TA       Slab      NaN      NaN          NaN       1040         2
#
#      KitchenQual  GarageArea
# 17            TA         516
# 39            Fa           0
# 90            TA         420
# 102           TA         410
# 156           TA         625
# 182           TA         252
# 259           TA         308
# 342           TA         400
# 362           Gd         672
# 371           TA         680
# 392           TA         294
# 520           TA           0
# 532           TA         392
# 533           Fa           0
# 553           Gd         520
# 646           TA         420
# 705           Fa           0
# 736           TA         400
# 749           TA         240
# 778           TA         630
# 868           TA         672
# 894           TA         400
# 897           TA         528
# 984           Gd         539
# 1000          Fa         528
# 1011          TA           0
# 1035          TA         290
# 1045          TA         452
# 1048          TA         336
# 1049          Gd         308
# 1090          TA         400
# 1179          TA           0
# 1216          TA         539
# 1218          TA           0
# 1232          TA         462
# 1321          TA         287
# 1412          TA         420

# %%
train_hp['BsmtFinType1'].value_counts(dropna=False)
# Out:
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# NaN     37
# Name: count, dtype: int64

# %% [markdown]
# ### Filling NA
# Data suggest that 'BsmtQual', 'BsmtCond', 'BsmtFinType1' can be considered as 'NA' (No Basement) but in our records we checked there is no record of NA and instead we imply it was treated as NaN because all the values in these features where it is NaN are same.

# %%
cols = ['BsmtQual', 'BsmtCond', 'BsmtFinType1']

train_hp[cols] = train_hp[cols].fillna('NA')

train_hp_records = train_hp.copy()

# %% [markdown]
# ### Convert Categorical Data Into Nominal Or Ordinal Depends On The Condition
# If the “order” lives only in your instinct and not in the data definition, don’t force it on the model.
#
# Example:
#
# Neighborhood: A < B < C
# But in reality:
# A might beat B for small houses
# B might beat C for old houses
# C might only be premium with certain features
# So the relationship is:
# Contextual
# Non-linear
# Interaction-heavy
# Trees can learn this — if you don’t constrain them.
#
# 🟦 One-Hot Encode:
# MSZoning, Neighborhood, Foundation, HouseStyle
#
# 🟩 Ordinal Encode:
# ExterQual, BsmtQual, BsmtCond, BsmtFinType1, KitchenQual

# %%
# First Convert Ordinal Ones
qual_map = {
    'NA': 0,
    'Po': 1,
    'Fa': 2,
    'TA': 3,
    'Gd': 4,
    'Ex': 5
}

ordinal_cols = [
    'ExterQual',
    'BsmtQual',
    'BsmtCond',
    'KitchenQual'
]

for col in ordinal_cols:
    train_hp[col] = train_hp[col].map(qual_map)

bsmtfin_map = {
    'NA': 0,
    'Unf': 1,
    'LwQ': 2,
    'Rec': 3,
    'BLQ': 4,
    'ALQ': 5,
    'GLQ': 6
}

train_hp['BsmtFinType1'] = train_hp['BsmtFinType1'].map(bsmtfin_map)

# %%
onehot_cols = [
    'MSZoning',
    'Neighborhood',
    'Foundation',
    'HouseStyle'
]

train_hp = pd.get_dummies(
    train_hp,
    columns=onehot_cols,
    drop_first=True
)

train_hp.head()
# Out:
#    SalePrice  LotArea  OverallQual  ExterQual  BsmtQual  BsmtCond  \
# 0     208500     8450            7          4         4         3
# 1     181500     9600            6          3         4         3
# 2     223500    11250            7          4         4         3
# 3     140000     9550            7          3         3         4
# 4     250000    14260            8          4         4         3
#
#    BsmtFinType1  GrLivArea  FullBath  KitchenQual  GarageArea  MSZoning_FV  \
# 0             6       1710         2            4         548        False
# 1             5       1262         2            3         460        False
# 2             6       1786         2            4         608        False
# 3             5       1717         1            4         642        False
# 4             6       2198         2            4         836        False
#
#    MSZoning_RH  MSZoning_RL  MSZoning_RM  Neighborhood_Blueste  \
# 0        False         True        False                 False
# 1        False         True        False                 False
# 2        False         True        False                 False
# 3        False         True        False                 False
# 4        False         True        False                 False
#
#    Neighborhood_BrDale  Neighborhood_BrkSide  Neighborhood_ClearCr  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                 False
# 3                False                 False                 False
# 4                False                 False                 False
#
#    Neighborhood_CollgCr  Neighborhood_Crawfor  Neighborhood_Edwards  \
# 0                  True                 False                 False
# 1                 False                 False                 False
# 2                  True                 False                 False
# 3                 False                  True                 False
# 4                 False                 False                 False
#
#    Neighborhood_Gilbert  Neighborhood_IDOTRR  Neighborhood_MeadowV  \
# 0                 False                False                 False
# 1                 False                False                 False
# 2                 False                False                 False
# 3                 False                False                 False
# 4                 False                False                 False
#
#    Neighborhood_Mitchel  Neighborhood_NAmes  Neighborhood_NPkVill  \
# 0                 False               False                 False
# 1                 False               False                 False
# 2                 False               False                 False
# 3                 False               False                 False
# 4                 False               False                 False
#
#    Neighborhood_NWAmes  Neighborhood_NoRidge  Neighborhood_NridgHt  \
# 0                False                 False                 False
# 1                False                 False                 False
# 2                False                 False                 False
# 3                False                 False                 False
# 4                False                  True                 False
#
#    Neighborhood_OldTown  Neighborhood_SWISU  Neighborhood_Sawyer  \
# 0                 False               False                False
# 1                 False               False                False
# 2                 False               False                False
# 3                 False               False                False
# 4                 False               False                False
#
#    Neighborhood_SawyerW  Neighborhood_Somerst  Neighborhood_StoneBr  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    Neighborhood_Timber  Neighborhood_Veenker  Foundation_CBlock  \
# 0                False                 False              False
# 1                False                  True               True
# 2                False                 False              False
# 3                False                 False              False
# 4                False                 False              False
#
#    Foundation_PConc  Foundation_Slab  Foundation_Stone  Foundation_Wood  \
# 0              True            False             False            False
# 1             False            False             False            False
# 2              True            False             False            False
# 3             False            False             False            False
# 4              True            False             False            False
#
#    HouseStyle_1.5Unf  HouseStyle_1Story  HouseStyle_2.5Fin  HouseStyle_2.5Unf  \
# 0              False              False              False              False
# 1              False               True              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    HouseStyle_2Story  HouseStyle_SFoyer  HouseStyle_SLvl
# 0               True              False            False
# 1              False              False            False
# 2               True              False            False
# 3               True              False            False
# 4               True              False            False

# %% [markdown]
# ### First Model Implication (Random Forest Regression)

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Split features & target
X = train_hp.drop(columns=['SalePrice'])
y = train_hp['SalePrice']
# Create bins (10 is a good default)
y_bins = pd.qcut(y, q=5, labels=False)

skf = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

train_rmse = []
val_rmse = []

rows = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y_bins), 1):

    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    # Random Forest
    model = RandomForestRegressor(
        n_estimators=300,
        max_depth=5,
        min_samples_leaf=30,
        random_state=1,
        n_jobs=-1
    )

    model.fit(X_train, y_train)

    # Predictions
    y_train_pred = model.predict(X_train)
    y_val_pred = model.predict(X_val)

    # RMSE
    rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred))
    rmse_val = np.sqrt(mean_squared_error(y_val, y_val_pred))

    train_rmse.append(rmse_train)
    val_rmse.append(rmse_val)

    for idx, actual, pred in zip(
        X_val.index, y_val.values, y_val_pred
    ):
        rows.append([idx, actual, round(pred, 2), round(actual - pred, 2), fold])

    print(f"Fold {fold}")
    print(f"Train RMSE: {rmse_train:.2f}")
    print(f"Val   RMSE: {rmse_val:.2f}")
    print("-" * 30)

# Summary
print("Average Train RMSE:", np.mean(train_rmse))
print("Average Val   RMSE:", np.mean(val_rmse))
# Out:
# Fold 1
# Train RMSE: 34526.73
# Val   RMSE: 41565.13
# ------------------------------
# Fold 2
# Train RMSE: 36566.29
# Val   RMSE: 34568.23
# ------------------------------
# Fold 3
# Train RMSE: 37325.19
# Val   RMSE: 29035.00
# ------------------------------
# Fold 4
# Train RMSE: 36507.44
# Val   RMSE: 33240.96
# ------------------------------
# Fold 5
# Train RMSE: 33356.54
# Val   RMSE: 49870.93
# ------------------------------
# Average Train RMSE: 35656.43829918067
# Average Val   RMSE: 37656.04985821863

# %%
pred_df = pd.DataFrame(
    rows,
    columns=["Index", "Actual", "Predicted", "Diff", "Fold"]
)

pred_df.head()
# Out:
#    Index  Actual  Predicted      Diff  Fold
# 0      6  307000  255167.78  51832.22     1
# 1      9  118000  123809.26  -5809.26     1
# 2     11  345000  367857.28 -22857.28     1
# 3     19  139000  128230.22  10769.78     1
# 4     20  325300  333888.65  -8588.65     1

# %%
pred_df.sort_values(by="Diff", ascending=False).head(10)
# Out:
#       Index  Actual  Predicted       Diff  Fold
# 1405   1182  745000  358245.39  386754.61     5
# 125     691  755000  379747.56  375252.44     1
# 1400   1169  625000  353740.39  271259.61     5
# 1347    898  611657  354393.96  257263.04     5
# 459     769  538000  323072.56  214927.44     2
# 466     803  582933  380143.72  202789.28     2
# 1377   1046  556581  357752.39  198828.61     5
# 82      440  555000  377215.13  177784.87     1
# 124     688  392000  241061.28  150938.72     1
# 1201    178  501837  355369.40  146467.60     5

# %%
top10 = (
    pred_df.assign(AbsDiff=pred_df["Diff"].abs())
           .sort_values("AbsDiff", ascending=False)
           .head(10)
)

# %%
full_debug_df = top10.merge(
    train_hp_records,
    left_on="Index",
    right_index=True,
    how="left"
)

full_debug_df
# Out:
#       Index  Actual  Predicted       Diff  Fold    AbsDiff  SalePrice  \
# 1405   1182  745000  358245.39  386754.61     5  386754.61     745000
# 125     691  755000  379747.56  375252.44     1  375252.44     755000
# 1400   1169  625000  353740.39  271259.61     5  271259.61     625000
# 1347    898  611657  354393.96  257263.04     5  257263.04     611657
# 459     769  538000  323072.56  214927.44     2  214927.44     538000
# 466     803  582933  380143.72  202789.28     2  202789.28     582933
# 1377   1046  556581  357752.39  198828.61     5  198828.61     556581
# 1433   1298  160000  358245.39 -198245.39     5  198245.39     160000
# 265    1349  122000  311688.61 -189688.61     1  189688.61     122000
# 82      440  555000  377215.13  177784.87     1  177784.87     555000
#
#      MSZoning  LotArea Neighborhood HouseStyle  OverallQual ExterQual  \
# 1405       RL    15623      NoRidge     2Story           10        Gd
# 125        RL    21535      NoRidge     2Story           10        Ex
# 1400       RL    35760      NoRidge     2Story           10        Gd
# 1347       RL    12919      NridgHt     1Story            9        Ex
# 459        RL    53504      StoneBr     2Story            8        Ex
# 466        RL    13891      NridgHt     2Story            9        Ex
# 1377       RL    16056      StoneBr     2Story            9        Gd
# 1433       RL    63887      Edwards     2Story           10        Ex
# 265        RM     5250      OldTown     2Story            8        TA
# 82         RL    15431      NridgHt     1Story           10        Ex
#
#      Foundation BsmtQual BsmtCond BsmtFinType1  GrLivArea  FullBath  \
# 1405      PConc       Ex       TA          GLQ       4476         3
# 125       PConc       Ex       TA          GLQ       4316         3
# 1400      PConc       Ex       TA          GLQ       3627         3
# 1347      PConc       Ex       TA          GLQ       2364         2
# 459       PConc       Gd       TA          ALQ       3279         3
# 466       PConc       Ex       TA          Unf       2822         3
# 1377      PConc       Ex       TA          GLQ       2868         3
# 1433      PConc       Ex       TA          GLQ       5642         2
# 265      BrkTil       TA       Fa          LwQ       2358         2
# 82        PConc       Ex       TA          GLQ       2402         2
#
#      KitchenQual  GarageArea
# 1405          Ex         813
# 125           Ex         832
# 1400          Gd         807
# 1347          Ex         820
# 459           Ex         841
# 466           Ex        1020
# 1377          Ex         716
# 1433          Ex        1418
# 265           TA           0
# 82            Ex         672

# %%
filtered_df = train_hp_records[
    (train_hp_records['MSZoning'] == 'RL') &
    (train_hp_records['Neighborhood'] == 'NoRidge') &
    (train_hp_records['HouseStyle'] == '2Story') &
    # (train_hp_records['OverallQual'] == 10)
    (train_hp_records['ExterQual'] == 'Gd') &
    (train_hp_records['Foundation'] == 'PConc') &
    # (train_hp_records['BsmtQual'] == 'Ex') &
    (train_hp_records['BsmtCond'] == 'TA') &
    (train_hp_records['BsmtFinType1'] == 'GLQ')
    # (train_hp_records['FullBath'] == 3) &
    # (train_hp_records['KitchenQual'] == 'Ex')
]

filtered_df
# Out:
#       SalePrice MSZoning  LotArea Neighborhood HouseStyle  OverallQual  \
# 4        250000       RL    14260      NoRidge     2Story            8
# 226      290000       RL     9950      NoRidge     2Story            7
# 231      403000       RL    15138      NoRidge     2Story            8
# 272      290000       RL    11764      NoRidge     2Story            8
# 318      260000       RL     9900      NoRidge     2Story            7
# 359      280000       RL    12011      NoRidge     2Story            8
# 423      315000       RL     9200      NoRidge     2Story            8
# 524      315750       RL    11787      NoRidge     2Story            7
# 564      268000       RL    13346      NoRidge     2Story            7
# 718      341000       RL    10542      NoRidge     2Story            7
# 763      337000       RL     9430      NoRidge     2Story            8
# 792      269790       RL     9920      NoRidge     2Story            7
# 981      336000       RL    12203      NoRidge     2Story            8
# 990      348000       RL     9452      NoRidge     2Story            8
# 1057     248000       RL    29959      NoRidge     2Story            7
# 1105     325000       RL    12256      NoRidge     2Story            8
# 1169     625000       RL    35760      NoRidge     2Story           10
# 1182     745000       RL    15623      NoRidge     2Story           10
# 1302     290000       RL    10120      NoRidge     2Story            8
# 1312     302000       RL     9572      NoRidge     2Story            8
# 1322     190000       RL    10186      NoRidge     2Story            7
# 1417     340000       RL    16545      NoRidge     2Story            8
# 1426     271000       RL    10944      NoRidge     2Story            7
#
#      ExterQual Foundation BsmtQual BsmtCond BsmtFinType1  GrLivArea  FullBath  \
# 4           Gd      PConc       Gd       TA          GLQ       2198         2
# 226         Gd      PConc       Gd       TA          GLQ       2520         2
# 231         Gd      PConc       Gd       TA          GLQ       2794         2
# 272         Gd      PConc       Gd       TA          GLQ       2270         2
# 318         Gd      PConc       Gd       TA          GLQ       2646         2
# 359         Gd      PConc       Gd       TA          GLQ       1924         2
# 423         Gd      PConc       Gd       TA          GLQ       2630         2
# 524         Gd      PConc       Gd       TA          GLQ       2398         2
# 564         Gd      PConc       Gd       TA          GLQ       2295         2
# 718         Gd      PConc       Gd       TA          GLQ       2418         2
# 763         Gd      PConc       Gd       TA          GLQ       2365         2
# 792         Gd      PConc       Gd       TA          GLQ       2013         2
# 981         Gd      PConc       Gd       TA          GLQ       2612         2
# 990         Gd      PConc       Gd       TA          GLQ       2392         2
# 1057        Gd      PConc       Gd       TA          GLQ       1850         2
# 1105        Gd      PConc       Ex       TA          GLQ       2622         2
# 1169        Gd      PConc       Ex       TA          GLQ       3627         3
# 1182        Gd      PConc       Ex       TA          GLQ       4476         3
# 1302        Gd      PConc       Gd       TA          GLQ       2526         2
# 1312        Gd      PConc       Ex       TA          GLQ       2810         2
# 1322        Gd      PConc       Gd       TA          GLQ       1923         2
# 1417        Gd      PConc       Gd       TA          GLQ       2450         2
# 1426        Gd      PConc       Gd       TA          GLQ       2127         2
#
#      KitchenQual  GarageArea
# 4             Gd         836
# 226           Gd         721
# 231           Ex         810
# 272           Gd         671
# 318           Gd         656
# 359           Gd         592
# 423           Gd         696
# 524           Gd         834
# 564           Gd         590
# 718           Gd         983
# 763           Gd         856
# 792           TA         455
# 981           Gd         676
# 990           Gd         870
# 1057          Gd         467
# 1105          Gd         712
# 1169          Gd         807
# 1182          Ex         813
# 1302          Gd         844
# 1312          Gd         750
# 1322          Gd         564
# 1417          Gd        1069
# 1426          Gd         525

# %%
abs_diff_df = (
    pred_df[pred_df["Index"].isin(filtered_df.index)]
        .assign(AbsDiff=lambda x: x["Diff"].abs())
)

# %%
final_df = (
    abs_diff_df.merge(
        train_hp_records,
        left_on="Index",
        right_index=True,
        how="left"
    )
)

final_df.sort_values('AbsDiff', ascending=False)
# Out:
#       Index  Actual  Predicted       Diff  Fold    AbsDiff  SalePrice  \
# 1405   1182  745000  358245.39  386754.61     5  386754.61     745000
# 1400   1169  625000  353740.39  271259.61     5  271259.61     625000
# 128     718  341000  247507.54   93492.46     1   93492.46     341000
# 923     231  403000  327262.20   75737.80     4   75737.80     403000
# 294       4  250000  315234.49  -65234.49     2   65234.49     250000
# 408     524  315750  252317.01   63432.99     2   63432.99     315750
# 736     792  269790  224309.10   45480.90     3   45480.90     269790
# 1368    990  348000  304781.08   43218.92     5   43218.92     348000
# 786    1057  248000  206331.76   41668.24     3   41668.24     248000
# 846    1322  190000  220295.44  -30295.44     3   30295.44     190000
# 458     763  337000  311697.29   25302.71     2   25302.71     337000
# 557    1302  290000  313570.85  -23570.85     2   23570.85     290000
# 762     981  336000  313142.32   22857.68     3   22857.68     336000
# 1209    226  290000  269355.32   20644.68     5   20644.68     290000
# 870    1426  271000  250356.74   20643.26     3   20643.26     271000
# 259    1312  302000  322405.99  -20405.99     1   20405.99     302000
# 101     564  268000  248066.23   19933.77     1   19933.77     268000
# 868    1417  340000  321666.83   18333.17     3   18333.17     340000
# 1231    359  280000  262830.64   17169.36     5   17169.36     280000
# 54      272  290000  306592.31  -16592.31     1   16592.31     290000
# 944     318  260000  250203.96    9796.04     4    9796.04     260000
# 389     423  315000  311395.62    3604.38     2    3604.38     315000
# 796    1105  325000  327917.65   -2917.65     3    2917.65     325000
#
#      MSZoning  LotArea Neighborhood HouseStyle  OverallQual ExterQual  \
# 1405       RL    15623      NoRidge     2Story           10        Gd
# 1400       RL    35760      NoRidge     2Story           10        Gd
# 128        RL    10542      NoRidge     2Story            7        Gd
# 923        RL    15138      NoRidge     2Story            8        Gd
# 294        RL    14260      NoRidge     2Story            8        Gd
# 408        RL    11787      NoRidge     2Story            7        Gd
# 736        RL     9920      NoRidge     2Story            7        Gd
# 1368       RL     9452      NoRidge     2Story            8        Gd
# 786        RL    29959      NoRidge     2Story            7        Gd
# 846        RL    10186      NoRidge     2Story            7        Gd
# 458        RL     9430      NoRidge     2Story            8        Gd
# 557        RL    10120      NoRidge     2Story            8        Gd
# 762        RL    12203      NoRidge     2Story            8        Gd
# 1209       RL     9950      NoRidge     2Story            7        Gd
# 870        RL    10944      NoRidge     2Story            7        Gd
# 259        RL     9572      NoRidge     2Story            8        Gd
# 101        RL    13346      NoRidge     2Story            7        Gd
# 868        RL    16545      NoRidge     2Story            8        Gd
# 1231       RL    12011      NoRidge     2Story            8        Gd
# 54         RL    11764      NoRidge     2Story            8        Gd
# 944        RL     9900      NoRidge     2Story            7        Gd
# 389        RL     9200      NoRidge     2Story            8        Gd
# 796        RL    12256      NoRidge     2Story            8        Gd
#
#      Foundation BsmtQual BsmtCond BsmtFinType1  GrLivArea  FullBath  \
# 1405      PConc       Ex       TA          GLQ       4476         3
# 1400      PConc       Ex       TA          GLQ       3627         3
# 128       PConc       Gd       TA          GLQ       2418         2
# 923       PConc       Gd       TA          GLQ       2794         2
# 294       PConc       Gd       TA          GLQ       2198         2
# 408       PConc       Gd       TA          GLQ       2398         2
# 736       PConc       Gd       TA          GLQ       2013         2
# 1368      PConc       Gd       TA          GLQ       2392         2
# 786       PConc       Gd       TA          GLQ       1850         2
# 846       PConc       Gd       TA          GLQ       1923         2
# 458       PConc       Gd       TA          GLQ       2365         2
# 557       PConc       Gd       TA          GLQ       2526         2
# 762       PConc       Gd       TA          GLQ       2612         2
# 1209      PConc       Gd       TA          GLQ       2520         2
# 870       PConc       Gd       TA          GLQ       2127         2
# 259       PConc       Ex       TA          GLQ       2810         2
# 101       PConc       Gd       TA          GLQ       2295         2
# 868       PConc       Gd       TA          GLQ       2450         2
# 1231      PConc       Gd       TA          GLQ       1924         2
# 54        PConc       Gd       TA          GLQ       2270         2
# 944       PConc       Gd       TA          GLQ       2646         2
# 389       PConc       Gd       TA          GLQ       2630         2
# 796       PConc       Ex       TA          GLQ       2622         2
#
#      KitchenQual  GarageArea
# 1405          Ex         813
# 1400          Gd         807
# 128           Gd         983
# 923           Ex         810
# 294           Gd         836
# 408           Gd         834
# 736           TA         455
# 1368          Gd         870
# 786           Gd         467
# 846           Gd         564
# 458           Gd         856
# 557           Gd         844
# 762           Gd         676
# 1209          Gd         721
# 870           Gd         525
# 259           Gd         750
# 101           Gd         590
# 868           Gd        1069
# 1231          Gd         592
# 54            Gd         671
# 944           Gd         656
# 389           Gd         696
# 796           Gd         712

# %% [markdown]
# ### Applying Log-transform

# %%
plt.figure(figsize=(12,5))

# Original
plt.subplot(1,2,1)
plt.hist(train_data['SalePrice'], bins=30)
plt.title("Original SalePrice")

# Log Transformed
plt.subplot(1,2,2)
plt.hist(np.log1p(train_data['SalePrice']), bins=30)
plt.title("Log(SalePrice)")

plt.show()

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Split features & target
X = train_hp.drop(columns=['SalePrice'])
y = np.log1p(train_hp['SalePrice'])
# Create bins (10 is a good default)
y_bins = pd.qcut(y, q=5, labels=False)

skf = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

train_rmse_log = []
val_rmse_log = []

train_rmse_actual = []
val_rmse_actual = []

all_actual = []
all_predicted = []

rows = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y_bins), 1):

    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

    # Random Forest
    model = RandomForestRegressor(
        n_estimators=300,
        max_depth=None,
        min_samples_leaf=5,
        random_state=1,
        n_jobs=-1
    )

    model.fit(X_train, y_train)

    # Predictions Log
    y_train_pred_log = model.predict(X_train)
    y_val_pred_log = model.predict(X_val)


    # Convert actual values back to original scale
    y_train_actual = np.expm1(y_train)
    y_val_actual = np.expm1(y_val)

    # Convert predictions back
    y_train_pred = np.expm1(y_train_pred_log)
    y_val_pred = np.expm1(y_val_pred_log)

    # -------- LOG SCALE RMSE --------
    rmse_train_log = np.sqrt(mean_squared_error(y_train, y_train_pred_log))
    rmse_val_log = np.sqrt(mean_squared_error(y_val, y_val_pred_log))
    
    train_rmse_log.append(rmse_train_log)
    val_rmse_log.append(rmse_val_log)

    rmse_train_actual = np.sqrt(mean_squared_error(y_train_actual, y_train_pred))
    rmse_val_actual = np.sqrt(mean_squared_error(y_val_actual, y_val_pred))
    
    train_rmse_actual.append(rmse_train_actual)
    val_rmse_actual.append(rmse_val_actual)

    for idx, actual, pred in zip(
        X_val.index, y_val_actual.values, y_val_pred
    ):
        rows.append([idx, actual, round(pred, 2), round(actual - pred, 2), fold])

    all_actual.extend(y_val_actual.values)
    all_predicted.extend(y_val_pred)

    print(f"Fold {fold}")
    print(f"Train RMSE (Log): {rmse_train_log:.4f}")
    print(f"Val   RMSE (Log): {rmse_val_log:.4f}")
    print(f"Train RMSE (Actual): {rmse_train_actual:.2f}")
    print(f"Val   RMSE (Actual): {rmse_val_actual:.2f}")
    print("-" * 40)

# Summary
print("Average Train RMSE:", np.mean(train_rmse))
print("Average Val   RMSE:", np.mean(val_rmse))
# Out:
# Fold 1
# Train RMSE (Log): 0.1172
# Val   RMSE (Log): 0.1577
# Train RMSE (Actual): 24500.57
# Val   RMSE (Actual): 35847.85
# ----------------------------------------
# Fold 2
# Train RMSE (Log): 0.1170
# Val   RMSE (Log): 0.1542
# Train RMSE (Actual): 25161.22
# Val   RMSE (Actual): 29657.83
# ----------------------------------------
# Fold 3
# Train RMSE (Log): 0.1177
# Val   RMSE (Log): 0.1522
# Train RMSE (Actual): 26406.74
# Val   RMSE (Actual): 25193.59
# ----------------------------------------
# Fold 4
# Train RMSE (Log): 0.1144
# Val   RMSE (Log): 0.1654
# Train RMSE (Actual): 25438.54
# Val   RMSE (Actual): 30217.29
# ----------------------------------------
# Fold 5
# Train RMSE (Log): 0.1128
# Val   RMSE (Log): 0.1689
# Train RMSE (Actual): 21988.75
# Val   RMSE (Actual): 45375.80
# ----------------------------------------
# Average Train RMSE: 35656.43829918067
# Average Val   RMSE: 37656.04985821863

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

plt.scatter(all_actual, all_predicted)

# Perfect prediction line
min_val = min(all_actual)
max_val = max(all_actual)
plt.plot([min_val, max_val], [min_val, max_val])

plt.xlabel("Actual SalePrice")
plt.ylabel("Predicted SalePrice")
plt.title("Actual vs Predicted (Validation Data)")

plt.show()

# %% [markdown]
# ## 2nd Phase
# ### - Evaluate Features On Log Sale Price Value To Evaluate Better
# ### - Adding more features which creates impact
# ### - Trying To Make Own Features which can be impactful
# ### - Change ML Model To XGBoost (Since it works good with high end values)

# %%
train_data["SalePrice_log"] = np.log1p(train_data["SalePrice"])

# %%
train_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 82 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   str
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   str
#  6   Alley          91 non-null     str
#  7   LotShape       1460 non-null   str
#  8   LandContour    1460 non-null   str
#  9   Utilities      1460 non-null   str
#  10  LotConfig      1460 non-null   str
#  11  LandSlope      1460 non-null   str
#  12  Neighborhood   1460 non-null   str
#  13  Condition1     1460 non-null   str
#  14  Condition2     1460 non-null   str
#  15  BldgType       1460 non-null   str
#  16  HouseStyle     1460 non-null   str
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   str
#  22  RoofMatl       1460 non-null   str
#  23  Exterior1st    1460 non-null   str
#  24  Exterior2nd    1460 non-null   str
#  25  MasVnrType     588 non-null    str
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   str
#  28  ExterCond      1460 non-null   str
#  29  Foundation     1460 non-null   str
#  30  BsmtQual       1423 non-null   str
#  31  BsmtCond       1423 non-null   str
#  32  BsmtExposure   1422 non-null   str
#  33  BsmtFinType1   1423 non-null   str
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   str
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   str
#  40  HeatingQC      1460 non-null   str
#  41  CentralAir     1460 non-null   str
#  42  Electrical     1459 non-null   str
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   str
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   str
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    str
#  58  GarageType     1379 non-null   str
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   str
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   str
#  64  GarageCond     1379 non-null   str
#  65  PavedDrive     1460 non-null   str
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      str
#  73  Fence          281 non-null    str
#  74  MiscFeature    54 non-null     str
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   str
#  79  SaleCondition  1460 non-null   str
#  80  SalePrice      1460 non-null   int64
#  81  SalePrice_log  1460 non-null   float64
# dtypes: float64(4), int64(35), str(43)
# memory usage: 935.4 KB

# %%
### Excluding some columns since they have too less data whihch will make model noisy

# %%
excluded_columns = [
    "Alley",
    # "MasVnrType",
    "FireplaceQu",
    "PoolQC",
    "Fence",
    "MiscFeature",
]

# %%
cols_to_exclude = set(excluded_columns)

train_data = train_data.loc[
    :, [col for col in train_data.columns if col not in cols_to_exclude]
]

train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     2Story            7            5       2003          2003     Gable
# 1     1Story            6            8       1976          1976     Gable
# 2     2Story            7            5       2001          2002     Gable
# 3     2Story            7            5       1915          1970     Gable
# 4     2Story            8            5       2000          2000     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0  CompShg     VinylSd     VinylSd    BrkFace       196.0        Gd        TA
# 1  CompShg     MetalSd     MetalSd        NaN         0.0        TA        TA
# 2  CompShg     VinylSd     VinylSd    BrkFace       162.0        Gd        TA
# 3  CompShg     Wd Sdng     Wd Shng        NaN         0.0        TA        TA
# 4  CompShg     VinylSd     VinylSd    BrkFace       350.0        Gd        TA
#
#   Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1  \
# 0      PConc       Gd       TA           No          GLQ         706
# 1     CBlock       Gd       TA           Gd          ALQ         978
# 2      PConc       Gd       TA           Mn          GLQ         486
# 3     BrkTil       TA       Gd           No          ALQ         216
# 4      PConc       Gd       TA           Av          GLQ         655
#
#   BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC  \
# 0          Unf           0        150          856    GasA        Ex
# 1          Unf           0        284         1262    GasA        Ex
# 2          Unf           0        434          920    GasA        Ex
# 3          Unf           0        540          756    GasA        Gd
# 4          Unf           0        490         1145    GasA        Ex
#
#   CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0          Y      SBrkr       856       854             0       1710
# 1          Y      SBrkr      1262         0             0       1262
# 2          Y      SBrkr       920       866             0       1786
# 3          Y      SBrkr       961       756             0       1717
# 4          Y      SBrkr      1145      1053             0       2198
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0             1             0         2         1             3             1
# 1             0             1         2         0             3             1
# 2             1             0         2         1             3             1
# 3             1             0         1         0             3             1
# 4             1             0         2         1             4             1
#
#   KitchenQual  TotRmsAbvGrd Functional  Fireplaces GarageType  GarageYrBlt  \
# 0          Gd             8        Typ           0     Attchd       2003.0
# 1          TA             6        Typ           1     Attchd       1976.0
# 2          Gd             6        Typ           1     Attchd       2001.0
# 3          Gd             7        Typ           1     Detchd       1998.0
# 4          Gd             9        Typ           1     Attchd       2000.0
#
#   GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0          RFn           2         548         TA         TA          Y
# 1          RFn           2         460         TA         TA          Y
# 2          RFn           2         608         TA         TA          Y
# 3          Unf           3         642         TA         TA          Y
# 4          RFn           3         836         TA         TA          Y
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0           0           61              0          0            0         0
# 1         298            0              0          0            0         0
# 2           0           42              0          0            0         0
# 3           0           35            272          0            0         0
# 4         192           84              0          0            0         0
#
#    MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice  SalePrice_log
# 0        0       2    2008       WD        Normal     208500      12.247699
# 1        0       5    2007       WD        Normal     181500      12.109016
# 2        0       9    2008       WD        Normal     223500      12.317171
# 3        0       2    2006       WD       Abnorml     140000      11.849405
# 4        0      12    2008       WD        Normal     250000      12.429220

# %%
train_data["MSSubClass"].value_counts()
# Out:
# MSSubClass
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: count, dtype: int64

# %%
import seaborn as sns

plt.figure(figsize=(14, 6))
sns.boxplot(
    data=train_data,
    x="MSSubClass",
    y="SalePrice_log"
)

plt.title("Feature Impact on log(SalePrice)")
plt.xticks(rotation=45)
plt.show()

# %%
train_data["LotFrontage"].value_counts()
# Out:
# LotFrontage
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 63.0      17
# 55.0      17
# 79.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 57.0      12
# 40.0      12
# 82.0      12
# 71.0      12
# 67.0      12
# 43.0      12
# 76.0      11
# 69.0      11
# 34.0      10
# 88.0      10
# 92.0      10
# 86.0      10
# 53.0      10
# 84.0       9
# 44.0       9
# 77.0       9
# 62.0       9
# 35.0       9
# 98.0       8
# 61.0       8
# 93.0       8
# 96.0       8
# 95.0       7
# 120.0      7
# 107.0      7
# 58.0       7
# 91.0       6
# 110.0      6
# 48.0       6
# 89.0       6
# 81.0       6
# 105.0      6
# 94.0       6
# 54.0       6
# 41.0       6
# 30.0       6
# 36.0       6
# 47.0       5
# 32.0       5
# 83.0       5
# 37.0       5
# 87.0       5
# 56.0       5
# 49.0       4
# 102.0      4
# 42.0       4
# 108.0      3
# 99.0       3
# 103.0      3
# 130.0      3
# 45.0       3
# 104.0      3
# 101.0      2
# 115.0      2
# 121.0      2
# 122.0      2
# 134.0      2
# 97.0       2
# 174.0      2
# 129.0      2
# 118.0      2
# 116.0      2
# 109.0      2
# 114.0      2
# 313.0      2
# 124.0      2
# 112.0      1
# 33.0       1
# 141.0      1
# 140.0      1
# 150.0      1
# 111.0      1
# 38.0       1
# 137.0      1
# 106.0      1
# 39.0       1
# 144.0      1
# 128.0      1
# 149.0      1
# 168.0      1
# 182.0      1
# 138.0      1
# 160.0      1
# 152.0      1
# 153.0      1
# 46.0       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.regplot(
    data=train_data,
    x="LotFrontage",
    y="SalePrice_log",
    scatter_kws={"alpha": 0.3},
    line_kws={"color": "red"}
)


plt.xlabel("LotFrontage")
plt.ylabel("log(SalePrice)")
plt.title("LotFrontage vs log(SalePrice)")
plt.show()

# %% [markdown]
# ### “This feature has a little noise but also has a moderate upward direction, so it can be helpful in combination and we can try it in the model.”

# %%
# NULL LotFrontage groups
null_stats = (
    train_data.loc[train_data["LotFrontage"].isna()]
    .groupby(["Neighborhood", "LotShape"])
    .agg(
        null_count=("LotFrontage", "size"),
        LotArea_median_null=("LotArea", "median")
    )
)

# NON-NULL LotFrontage groups
non_null_stats = (
    train_data.loc[train_data["LotFrontage"].notna()]
    .groupby(["Neighborhood", "LotShape"])
    .agg(
        LotFrontage_median=("LotFrontage", "median"),
        LotFrontage_count=("LotFrontage", "count"),
        LotArea_median_non_null=("LotArea", "median")
    )
)

# Combine
result = (
    null_stats
    .join(non_null_stats)
    .sort_values("null_count", ascending=False)
)

result["LotArea_pct_diff"] = round(abs(
    (result["LotArea_median_null"] - result["LotArea_median_non_null"])
    / result["LotArea_median_non_null"]
) * 100, 2)

result
# Out:
#                        null_count  LotArea_median_null  LotFrontage_median  \
# Neighborhood LotShape
# NAmes        IR1               34              11333.0                75.5
# NWAmes       IR1               21              12046.0                81.0
# Gilbert      IR1               20               9376.5                65.0
# Sawyer       IR1               19               9945.0                76.0
# CollgCr      Reg               16               8682.5                70.0
# Mitchel      IR1               11               9947.0                55.0
# Crawfor      IR1                9              14778.0                79.5
# CollgCr      IR1                7               9531.0                72.0
# Edwards      IR1                7              11500.0                67.0
# Timber       IR1                7              15498.0                73.0
# NWAmes       Reg                6               9845.0                80.0
# Sawyer       Reg                6              13467.0                70.5
# Somerst      Reg                6               2384.0                73.5
# ClearCr      IR1                6              16829.0                79.0
#              Reg                5              13500.0                80.0
# Gilbert      Reg                5               7851.0                65.0
# NoRidge      IR1                5              13346.0                92.0
# BrkSide      Reg                4               8150.0                51.0
# ClearCr      IR2                4              84128.0                75.0
# SawyerW      IR1                4               9316.5                80.0
# StoneBr      IR1                4               6188.5                69.0
# SawyerW      Reg                4              10050.0                65.0
# Veenker      IR1                4              13703.5                50.0
# NAmes        Reg                4               9490.0                72.0
# Gilbert      IR2                4              13450.0               122.0
# Blmngtn      Reg                3               3196.0                43.0
# OldTown      Reg                3               5100.0                60.0
# BrkSide      IR1                3               7015.0                58.0
# IDOTRR       Reg                2               6824.0                60.0
# MeadowV      Reg                2               2319.5                21.0
# NoRidge      Reg                2              11200.0                89.5
# Somerst      IR2                2               4754.0                54.0
# NPkVill      IR1                2               4928.0                 NaN
# Mitchel      Reg                2              18481.5                75.0
# IDOTRR       IR1                1               7920.0               105.0
# Gilbert      IR3                1              24682.0               168.0
# Crawfor      Reg                1              21000.0                66.0
# Edwards      Reg                1              17140.0                65.0
# CollgCr      IR2                1              14781.0                48.0
# NAmes        IR3                1              12155.0                 NaN
# NoRidge      IR2                1              29959.0                55.0
# NWAmes       IR2                1              20781.0                 NaN
# OldTown      IR1                1              12358.0                62.5
# NridgHt      IR1                1               3136.0                84.0
# SWISU        IR1                1              12155.0                 NaN
#              Reg                1               7082.0                60.0
# SawyerW      IR3                1              16196.0                 NaN
# Sawyer       IR2                1              12968.0                 NaN
# StoneBr      Reg                1               3696.0                41.0
# Timber       IR2                1              11170.0                 NaN
#
#                        LotFrontage_count  LotArea_median_non_null  \
# Neighborhood LotShape
# NAmes        IR1                    32.0                  10186.0
# NWAmes       IR1                    10.0                  12166.5
# Gilbert      IR1                    33.0                   9967.0
# Sawyer       IR1                    12.0                  10049.5
# CollgCr      Reg                    70.0                   8766.5
# Mitchel      IR1                     9.0                  12209.0
# Crawfor      IR1                    16.0                  10550.0
# CollgCr      IR1                    46.0                  10073.0
# Edwards      IR1                    10.0                   9926.0
# Timber       IR1                    17.0                  12416.0
# NWAmes       Reg                    35.0                  10400.0
# Sawyer       Reg                    36.0                   8770.0
# Somerst      Reg                    58.0                   8844.0
# ClearCr      IR1                     7.0                  18030.0
#              Reg                     5.0                  14000.0
# Gilbert      Reg                    10.0                   9181.0
# NoRidge      IR1                    21.0                  12203.0
# BrkSide      Reg                    39.0                   6180.0
# ClearCr      IR2                     1.0                  45600.0
# SawyerW      IR1                    14.0                  10091.5
# StoneBr      IR1                    13.0                  11302.0
# SawyerW      Reg                    35.0                   8450.0
# Veenker      IR1                     4.0                  10807.0
# NAmes        Reg                   153.0                   9020.0
# Gilbert      IR2                     3.0                  12589.0
# Blmngtn      Reg                    14.0                   3182.0
# OldTown      Reg                    97.0                   7740.0
# BrkSide      IR1                    12.0                   6239.5
# IDOTRR       Reg                    32.0                   8071.0
# MeadowV      Reg                    15.0                   1936.0
# NoRidge      Reg                    10.0                  10331.0
# Somerst      IR2                     2.0                  12589.0
# NPkVill      IR1                     NaN                      NaN
# Mitchel      Reg                    27.0                   9858.0
# IDOTRR       IR1                     1.0                   8470.0
# Gilbert      IR3                     3.0                  21930.0
# Crawfor      Reg                    25.0                  10594.0
# Edwards      Reg                    81.0                   8877.0
# CollgCr      IR2                     9.0                  12137.0
# NAmes        IR3                     NaN                      NaN
# NoRidge      IR2                     2.0                  31679.5
# NWAmes       IR2                     NaN                      NaN
# OldTown      IR1                    10.0                   9485.0
# NridgHt      IR1                    32.0                  11227.0
# SWISU        IR1                     NaN                      NaN
#              Reg                    22.0                   8102.0
# SawyerW      IR3                     NaN                      NaN
# Sawyer       IR2                     NaN                      NaN
# StoneBr      Reg                     5.0                   5330.0
# Timber       IR2                     NaN                      NaN
#
#                        LotArea_pct_diff
# Neighborhood LotShape
# NAmes        IR1                  11.26
# NWAmes       IR1                   0.99
# Gilbert      IR1                   5.92
# Sawyer       IR1                   1.04
# CollgCr      Reg                   0.96
# Mitchel      IR1                  18.53
# Crawfor      IR1                  40.08
# CollgCr      IR1                   5.38
# Edwards      IR1                  15.86
# Timber       IR1                  24.82
# NWAmes       Reg                   5.34
# Sawyer       Reg                  53.56
# Somerst      Reg                  73.04
# ClearCr      IR1                   6.66
#              Reg                   3.57
# Gilbert      Reg                  14.49
# NoRidge      IR1                   9.37
# BrkSide      Reg                  31.88
# ClearCr      IR2                  84.49
# SawyerW      IR1                   7.68
# StoneBr      IR1                  45.24
# SawyerW      Reg                  18.93
# Veenker      IR1                  26.80
# NAmes        Reg                   5.21
# Gilbert      IR2                   6.84
# Blmngtn      Reg                   0.44
# OldTown      Reg                  34.11
# BrkSide      IR1                  12.43
# IDOTRR       Reg                  15.45
# MeadowV      Reg                  19.81
# NoRidge      Reg                   8.41
# Somerst      IR2                  62.24
# NPkVill      IR1                    NaN
# Mitchel      Reg                  87.48
# IDOTRR       IR1                   6.49
# Gilbert      IR3                  12.55
# Crawfor      Reg                  98.23
# Edwards      Reg                  93.08
# CollgCr      IR2                  21.78
# NAmes        IR3                    NaN
# NoRidge      IR2                   5.43
# NWAmes       IR2                    NaN
# OldTown      IR1                  30.29
# NridgHt      IR1                  72.07
# SWISU        IR1                    NaN
#              Reg                  12.59
# SawyerW      IR3                    NaN
# Sawyer       IR2                    NaN
# StoneBr      Reg                  30.66
# Timber       IR2                    NaN

# %%
plt.figure(figsize=(8, 6))
sns.regplot(
    data=train_data,
    x="LotFrontage",
    y="LotArea",
    scatter_kws={"alpha": 0.3},
    line_kws={"color": "red"}
)


plt.xlabel("LotFrontage")
plt.ylabel("LotArea")
plt.title("LotFrontage vs LotArea")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(14, 6))
sns.boxplot(
    data=train_data,
    x="Neighborhood",
    y="LotFrontage"
)

plt.title("Neighborhood on LotFrontage")
plt.xticks(rotation=45)
plt.show()

# %%
neigh_stats = (
    train_data.loc[train_data["LotFrontage"].notna()]
    .groupby("Neighborhood")
    .agg(
        neigh_median_frontage=("LotFrontage", "median"),
        neigh_count=("LotFrontage", "count")
    )
)
result = result.join(neigh_stats, on="Neighborhood")

# %% [markdown]
# ### Filling LotFrontage Data

# %%
def classify_group(row):
    count = row["LotFrontage_count"]
    area_diff = row["LotArea_pct_diff"]
    neigh_count = row["neigh_count"]

    if pd.notna(count) and count >= 10 and area_diff <= 15:
        return "HIGH"
    elif pd.notna(count) and count >= 5 and area_diff <= 30:
        return "MEDIUM"
    elif pd.notna(count) and count >= 5:
        return "LOW_AREA_MISMATCH"
    elif pd.notna(neigh_count) and neigh_count >= 10:
        return "USE_NEIGHBORHOOD_MEDIAN"
    else:
        return "FALLBACK"

result["confidence"] = result.apply(classify_group, axis=1)

# %%
import numpy as np

global_median = round(train_data["LotFrontage"].median(), 2)

def compute_imputation(row):
    conf = row["confidence"]
    median_front = row["LotFrontage_median"]
    null_area = row["LotArea_median_null"]
    non_null_area = row["LotArea_median_non_null"]
    neigh_median_frontage = row["neigh_median_frontage"]

    if conf == "HIGH":
        return round(median_front, 2)

    elif conf == "MEDIUM":
        if pd.notna(null_area) and pd.notna(non_null_area):
            # Why sqrt?
            # Because area is 2D and frontage is 1D.
            # This stabilizes scaling.
            scale = np.sqrt(null_area / non_null_area) 
            return round(median_front * scale, 2)
        else:
            return round(median_front, 2)

    elif conf == "LOW_AREA_MISMATCH":
        return round(median_front, 2)

    elif conf == "USE_NEIGHBORHOOD_MEDIAN":
        return round(neigh_median_frontage, 2)

    else:
        return global_median   # fallback will be handled later

result["imputed_preview"] = result.apply(compute_imputation, axis=1)

# %%
def explain(row):
    return f"{row['confidence']} | count={row['LotFrontage_count']} | area_diff={row['LotArea_pct_diff']}%"

result["reason"] = result.apply(explain, axis=1)

# %%
result
# Out:
#                        null_count  LotArea_median_null  LotFrontage_median  \
# Neighborhood LotShape
# NAmes        IR1               34              11333.0                75.5
# NWAmes       IR1               21              12046.0                81.0
# Gilbert      IR1               20               9376.5                65.0
# Sawyer       IR1               19               9945.0                76.0
# CollgCr      Reg               16               8682.5                70.0
# Mitchel      IR1               11               9947.0                55.0
# Crawfor      IR1                9              14778.0                79.5
# CollgCr      IR1                7               9531.0                72.0
# Edwards      IR1                7              11500.0                67.0
# Timber       IR1                7              15498.0                73.0
# NWAmes       Reg                6               9845.0                80.0
# Sawyer       Reg                6              13467.0                70.5
# Somerst      Reg                6               2384.0                73.5
# ClearCr      IR1                6              16829.0                79.0
#              Reg                5              13500.0                80.0
# Gilbert      Reg                5               7851.0                65.0
# NoRidge      IR1                5              13346.0                92.0
# BrkSide      Reg                4               8150.0                51.0
# ClearCr      IR2                4              84128.0                75.0
# SawyerW      IR1                4               9316.5                80.0
# StoneBr      IR1                4               6188.5                69.0
# SawyerW      Reg                4              10050.0                65.0
# Veenker      IR1                4              13703.5                50.0
# NAmes        Reg                4               9490.0                72.0
# Gilbert      IR2                4              13450.0               122.0
# Blmngtn      Reg                3               3196.0                43.0
# OldTown      Reg                3               5100.0                60.0
# BrkSide      IR1                3               7015.0                58.0
# IDOTRR       Reg                2               6824.0                60.0
# MeadowV      Reg                2               2319.5                21.0
# NoRidge      Reg                2              11200.0                89.5
# Somerst      IR2                2               4754.0                54.0
# NPkVill      IR1                2               4928.0                 NaN
# Mitchel      Reg                2              18481.5                75.0
# IDOTRR       IR1                1               7920.0               105.0
# Gilbert      IR3                1              24682.0               168.0
# Crawfor      Reg                1              21000.0                66.0
# Edwards      Reg                1              17140.0                65.0
# CollgCr      IR2                1              14781.0                48.0
# NAmes        IR3                1              12155.0                 NaN
# NoRidge      IR2                1              29959.0                55.0
# NWAmes       IR2                1              20781.0                 NaN
# OldTown      IR1                1              12358.0                62.5
# NridgHt      IR1                1               3136.0                84.0
# SWISU        IR1                1              12155.0                 NaN
#              Reg                1               7082.0                60.0
# SawyerW      IR3                1              16196.0                 NaN
# Sawyer       IR2                1              12968.0                 NaN
# StoneBr      Reg                1               3696.0                41.0
# Timber       IR2                1              11170.0                 NaN
#
#                        LotFrontage_count  LotArea_median_non_null  \
# Neighborhood LotShape
# NAmes        IR1                    32.0                  10186.0
# NWAmes       IR1                    10.0                  12166.5
# Gilbert      IR1                    33.0                   9967.0
# Sawyer       IR1                    12.0                  10049.5
# CollgCr      Reg                    70.0                   8766.5
# Mitchel      IR1                     9.0                  12209.0
# Crawfor      IR1                    16.0                  10550.0
# CollgCr      IR1                    46.0                  10073.0
# Edwards      IR1                    10.0                   9926.0
# Timber       IR1                    17.0                  12416.0
# NWAmes       Reg                    35.0                  10400.0
# Sawyer       Reg                    36.0                   8770.0
# Somerst      Reg                    58.0                   8844.0
# ClearCr      IR1                     7.0                  18030.0
#              Reg                     5.0                  14000.0
# Gilbert      Reg                    10.0                   9181.0
# NoRidge      IR1                    21.0                  12203.0
# BrkSide      Reg                    39.0                   6180.0
# ClearCr      IR2                     1.0                  45600.0
# SawyerW      IR1                    14.0                  10091.5
# StoneBr      IR1                    13.0                  11302.0
# SawyerW      Reg                    35.0                   8450.0
# Veenker      IR1                     4.0                  10807.0
# NAmes        Reg                   153.0                   9020.0
# Gilbert      IR2                     3.0                  12589.0
# Blmngtn      Reg                    14.0                   3182.0
# OldTown      Reg                    97.0                   7740.0
# BrkSide      IR1                    12.0                   6239.5
# IDOTRR       Reg                    32.0                   8071.0
# MeadowV      Reg                    15.0                   1936.0
# NoRidge      Reg                    10.0                  10331.0
# Somerst      IR2                     2.0                  12589.0
# NPkVill      IR1                     NaN                      NaN
# Mitchel      Reg                    27.0                   9858.0
# IDOTRR       IR1                     1.0                   8470.0
# Gilbert      IR3                     3.0                  21930.0
# Crawfor      Reg                    25.0                  10594.0
# Edwards      Reg                    81.0                   8877.0
# CollgCr      IR2                     9.0                  12137.0
# NAmes        IR3                     NaN                      NaN
# NoRidge      IR2                     2.0                  31679.5
# NWAmes       IR2                     NaN                      NaN
# OldTown      IR1                    10.0                   9485.0
# NridgHt      IR1                    32.0                  11227.0
# SWISU        IR1                     NaN                      NaN
#              Reg                    22.0                   8102.0
# SawyerW      IR3                     NaN                      NaN
# Sawyer       IR2                     NaN                      NaN
# StoneBr      Reg                     5.0                   5330.0
# Timber       IR2                     NaN                      NaN
#
#                        LotArea_pct_diff  neigh_median_frontage  neigh_count  \
# Neighborhood LotShape
# NAmes        IR1                  11.26                   73.0          186
# NWAmes       IR1                   0.99                   80.0           45
# Gilbert      IR1                   5.92                   65.0           49
# Sawyer       IR1                   1.04                   71.0           48
# CollgCr      Reg                   0.96                   70.0          126
# Mitchel      IR1                  18.53                   73.0           36
# Crawfor      IR1                  40.08                   74.0           41
# CollgCr      IR1                   5.38                   70.0          126
# Edwards      IR1                  15.86                   65.5           92
# Timber       IR1                  24.82                   85.0           30
# NWAmes       Reg                   5.34                   80.0           45
# Sawyer       Reg                  53.56                   71.0           48
# Somerst      Reg                  73.04                   73.5           78
# ClearCr      IR1                   6.66                   80.0           13
#              Reg                   3.57                   80.0           13
# Gilbert      Reg                  14.49                   65.0           49
# NoRidge      IR1                   9.37                   91.0           33
# BrkSide      Reg                  31.88                   52.0           51
# ClearCr      IR2                  84.49                   80.0           13
# SawyerW      IR1                   7.68                   66.5           50
# StoneBr      IR1                  45.24                   61.5           20
# SawyerW      Reg                  18.93                   66.5           50
# Veenker      IR1                  26.80                   68.0            7
# NAmes        Reg                   5.21                   73.0          186
# Gilbert      IR2                   6.84                   65.0           49
# Blmngtn      Reg                   0.44                   43.0           14
# OldTown      Reg                  34.11                   60.0          109
# BrkSide      IR1                  12.43                   52.0           51
# IDOTRR       Reg                  15.45                   60.0           34
# MeadowV      Reg                  19.81                   21.0           15
# NoRidge      Reg                   8.41                   91.0           33
# Somerst      IR2                  62.24                   73.5           78
# NPkVill      IR1                    NaN                   24.0            7
# Mitchel      Reg                  87.48                   73.0           36
# IDOTRR       IR1                   6.49                   60.0           34
# Gilbert      IR3                  12.55                   65.0           49
# Crawfor      Reg                  98.23                   74.0           41
# Edwards      Reg                  93.08                   65.5           92
# CollgCr      IR2                  21.78                   70.0          126
# NAmes        IR3                    NaN                   73.0          186
# NoRidge      IR2                   5.43                   91.0           33
# NWAmes       IR2                    NaN                   80.0           45
# OldTown      IR1                  30.29                   60.0          109
# NridgHt      IR1                  72.07                   88.5           76
# SWISU        IR1                    NaN                   60.0           23
#              Reg                  12.59                   60.0           23
# SawyerW      IR3                    NaN                   66.5           50
# Sawyer       IR2                    NaN                   71.0           48
# StoneBr      Reg                  30.66                   61.5           20
# Timber       IR2                    NaN                   85.0           30
#
#                                     confidence  imputed_preview  \
# Neighborhood LotShape
# NAmes        IR1                          HIGH            75.50
# NWAmes       IR1                          HIGH            81.00
# Gilbert      IR1                          HIGH            65.00
# Sawyer       IR1                          HIGH            76.00
# CollgCr      Reg                          HIGH            70.00
# Mitchel      IR1                        MEDIUM            49.64
# Crawfor      IR1             LOW_AREA_MISMATCH            79.50
# CollgCr      IR1                          HIGH            72.00
# Edwards      IR1                        MEDIUM            72.12
# Timber       IR1                        MEDIUM            81.56
# NWAmes       Reg                          HIGH            80.00
# Sawyer       Reg             LOW_AREA_MISMATCH            70.50
# Somerst      Reg             LOW_AREA_MISMATCH            73.50
# ClearCr      IR1                        MEDIUM            76.32
#              Reg                        MEDIUM            78.56
# Gilbert      Reg                          HIGH            65.00
# NoRidge      IR1                          HIGH            92.00
# BrkSide      Reg             LOW_AREA_MISMATCH            51.00
# ClearCr      IR2       USE_NEIGHBORHOOD_MEDIAN            80.00
# SawyerW      IR1                          HIGH            80.00
# StoneBr      IR1             LOW_AREA_MISMATCH            69.00
# SawyerW      Reg                        MEDIUM            70.89
# Veenker      IR1                      FALLBACK            69.00
# NAmes        Reg                          HIGH            72.00
# Gilbert      IR2       USE_NEIGHBORHOOD_MEDIAN            65.00
# Blmngtn      Reg                          HIGH            43.00
# OldTown      Reg             LOW_AREA_MISMATCH            60.00
# BrkSide      IR1                          HIGH            58.00
# IDOTRR       Reg                        MEDIUM            55.17
# MeadowV      Reg                        MEDIUM            22.99
# NoRidge      Reg                          HIGH            89.50
# Somerst      IR2       USE_NEIGHBORHOOD_MEDIAN            73.50
# NPkVill      IR1                      FALLBACK            69.00
# Mitchel      Reg             LOW_AREA_MISMATCH            75.00
# IDOTRR       IR1       USE_NEIGHBORHOOD_MEDIAN            60.00
# Gilbert      IR3       USE_NEIGHBORHOOD_MEDIAN            65.00
# Crawfor      Reg             LOW_AREA_MISMATCH            66.00
# Edwards      Reg             LOW_AREA_MISMATCH            65.00
# CollgCr      IR2                        MEDIUM            52.97
# NAmes        IR3       USE_NEIGHBORHOOD_MEDIAN            73.00
# NoRidge      IR2       USE_NEIGHBORHOOD_MEDIAN            91.00
# NWAmes       IR2       USE_NEIGHBORHOOD_MEDIAN            80.00
# OldTown      IR1             LOW_AREA_MISMATCH            62.50
# NridgHt      IR1             LOW_AREA_MISMATCH            84.00
# SWISU        IR1       USE_NEIGHBORHOOD_MEDIAN            60.00
#              Reg                          HIGH            60.00
# SawyerW      IR3       USE_NEIGHBORHOOD_MEDIAN            66.50
# Sawyer       IR2       USE_NEIGHBORHOOD_MEDIAN            71.00
# StoneBr      Reg             LOW_AREA_MISMATCH            41.00
# Timber       IR2       USE_NEIGHBORHOOD_MEDIAN            85.00
#
#                                                                   reason
# Neighborhood LotShape
# NAmes        IR1                    HIGH | count=32.0 | area_diff=11.26%
# NWAmes       IR1                     HIGH | count=10.0 | area_diff=0.99%
# Gilbert      IR1                     HIGH | count=33.0 | area_diff=5.92%
# Sawyer       IR1                     HIGH | count=12.0 | area_diff=1.04%
# CollgCr      Reg                     HIGH | count=70.0 | area_diff=0.96%
# Mitchel      IR1                   MEDIUM | count=9.0 | area_diff=18.53%
# Crawfor      IR1       LOW_AREA_MISMATCH | count=16.0 | area_diff=40.08%
# CollgCr      IR1                     HIGH | count=46.0 | area_diff=5.38%
# Edwards      IR1                  MEDIUM | count=10.0 | area_diff=15.86%
# Timber       IR1                  MEDIUM | count=17.0 | area_diff=24.82%
# NWAmes       Reg                     HIGH | count=35.0 | area_diff=5.34%
# Sawyer       Reg       LOW_AREA_MISMATCH | count=36.0 | area_diff=53.56%
# Somerst      Reg       LOW_AREA_MISMATCH | count=58.0 | area_diff=73.04%
# ClearCr      IR1                    MEDIUM | count=7.0 | area_diff=6.66%
#              Reg                    MEDIUM | count=5.0 | area_diff=3.57%
# Gilbert      Reg                    HIGH | count=10.0 | area_diff=14.49%
# NoRidge      IR1                     HIGH | count=21.0 | area_diff=9.37%
# BrkSide      Reg       LOW_AREA_MISMATCH | count=39.0 | area_diff=31.88%
# ClearCr      IR2       USE_NEIGHBORHOOD_MEDIAN | count=1.0 | area_dif...
# SawyerW      IR1                     HIGH | count=14.0 | area_diff=7.68%
# StoneBr      IR1       LOW_AREA_MISMATCH | count=13.0 | area_diff=45.24%
# SawyerW      Reg                  MEDIUM | count=35.0 | area_diff=18.93%
# Veenker      IR1                  FALLBACK | count=4.0 | area_diff=26.8%
# NAmes        Reg                    HIGH | count=153.0 | area_diff=5.21%
# Gilbert      IR2       USE_NEIGHBORHOOD_MEDIAN | count=3.0 | area_dif...
# Blmngtn      Reg                     HIGH | count=14.0 | area_diff=0.44%
# OldTown      Reg       LOW_AREA_MISMATCH | count=97.0 | area_diff=34.11%
# BrkSide      IR1                    HIGH | count=12.0 | area_diff=12.43%
# IDOTRR       Reg                  MEDIUM | count=32.0 | area_diff=15.45%
# MeadowV      Reg                  MEDIUM | count=15.0 | area_diff=19.81%
# NoRidge      Reg                     HIGH | count=10.0 | area_diff=8.41%
# Somerst      IR2       USE_NEIGHBORHOOD_MEDIAN | count=2.0 | area_dif...
# NPkVill      IR1                   FALLBACK | count=nan | area_diff=nan%
# Mitchel      Reg       LOW_AREA_MISMATCH | count=27.0 | area_diff=87.48%
# IDOTRR       IR1       USE_NEIGHBORHOOD_MEDIAN | count=1.0 | area_dif...
# Gilbert      IR3       USE_NEIGHBORHOOD_MEDIAN | count=3.0 | area_dif...
# Crawfor      Reg       LOW_AREA_MISMATCH | count=25.0 | area_diff=98.23%
# Edwards      Reg       LOW_AREA_MISMATCH | count=81.0 | area_diff=93.08%
# CollgCr      IR2                   MEDIUM | count=9.0 | area_diff=21.78%
# NAmes        IR3       USE_NEIGHBORHOOD_MEDIAN | count=nan | area_dif...
# NoRidge      IR2       USE_NEIGHBORHOOD_MEDIAN | count=2.0 | area_dif...
# NWAmes       IR2       USE_NEIGHBORHOOD_MEDIAN | count=nan | area_dif...
# OldTown      IR1       LOW_AREA_MISMATCH | count=10.0 | area_diff=30.29%
# NridgHt      IR1       LOW_AREA_MISMATCH | count=32.0 | area_diff=72.07%
# SWISU        IR1       USE_NEIGHBORHOOD_MEDIAN | count=nan | area_dif...
#              Reg                    HIGH | count=22.0 | area_diff=12.59%
# SawyerW      IR3       USE_NEIGHBORHOOD_MEDIAN | count=nan | area_dif...
# Sawyer       IR2       USE_NEIGHBORHOOD_MEDIAN | count=nan | area_dif...
# StoneBr      Reg        LOW_AREA_MISMATCH | count=5.0 | area_diff=30.66%
# Timber       IR2       USE_NEIGHBORHOOD_MEDIAN | count=nan | area_dif...

# %%
result["imputed_preview"].isna().sum()
# Out:
# np.int64(0)

# %%
result["imputed_preview"].describe()
# Out:
# count    50.000000
# mean     68.884400
# std      13.157854
# min      22.990000
# 25%      63.125000
# 50%      70.695000
# 75%      78.000000
# max      92.000000
# Name: imputed_preview, dtype: float64

# %%
impute_map = result["imputed_preview"].to_dict()

def fill_lotfrontage(row):
    if pd.notna(row["LotFrontage"]):
        return row["LotFrontage"]

    key = (row["Neighborhood"], row["LotShape"])

    if key in impute_map:
        return impute_map[key]
    else:
        return global_median

train_data["LotFrontage"] = train_data.apply(fill_lotfrontage, axis=1)

# %%
train_data["LotFrontage"].isna().sum()
# Out:
# np.int64(0)

# %%
train_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   str
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   str
#  6   LotShape       1460 non-null   str
#  7   LandContour    1460 non-null   str
#  8   Utilities      1460 non-null   str
#  9   LotConfig      1460 non-null   str
#  10  LandSlope      1460 non-null   str
#  11  Neighborhood   1460 non-null   str
#  12  Condition1     1460 non-null   str
#  13  Condition2     1460 non-null   str
#  14  BldgType       1460 non-null   str
#  15  HouseStyle     1460 non-null   str
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  YearBuilt      1460 non-null   int64
#  19  YearRemodAdd   1460 non-null   int64
#  20  RoofStyle      1460 non-null   str
#  21  RoofMatl       1460 non-null   str
#  22  Exterior1st    1460 non-null   str
#  23  Exterior2nd    1460 non-null   str
#  24  MasVnrType     588 non-null    str
#  25  MasVnrArea     1452 non-null   float64
#  26  ExterQual      1460 non-null   str
#  27  ExterCond      1460 non-null   str
#  28  Foundation     1460 non-null   str
#  29  BsmtQual       1423 non-null   str
#  30  BsmtCond       1423 non-null   str
#  31  BsmtExposure   1422 non-null   str
#  32  BsmtFinType1   1423 non-null   str
#  33  BsmtFinSF1     1460 non-null   int64
#  34  BsmtFinType2   1422 non-null   str
#  35  BsmtFinSF2     1460 non-null   int64
#  36  BsmtUnfSF      1460 non-null   int64
#  37  TotalBsmtSF    1460 non-null   int64
#  38  Heating        1460 non-null   str
#  39  HeatingQC      1460 non-null   str
#  40  CentralAir     1460 non-null   str
#  41  Electrical     1459 non-null   str
#  42  1stFlrSF       1460 non-null   int64
#  43  2ndFlrSF       1460 non-null   int64
#  44  LowQualFinSF   1460 non-null   int64
#  45  GrLivArea      1460 non-null   int64
#  46  BsmtFullBath   1460 non-null   int64
#  47  BsmtHalfBath   1460 non-null   int64
#  48  FullBath       1460 non-null   int64
#  49  HalfBath       1460 non-null   int64
#  50  BedroomAbvGr   1460 non-null   int64
#  51  KitchenAbvGr   1460 non-null   int64
#  52  KitchenQual    1460 non-null   str
#  53  TotRmsAbvGrd   1460 non-null   int64
#  54  Functional     1460 non-null   str
#  55  Fireplaces     1460 non-null   int64
#  56  GarageType     1379 non-null   str
#  57  GarageYrBlt    1379 non-null   float64
#  58  GarageFinish   1379 non-null   str
#  59  GarageCars     1460 non-null   int64
#  60  GarageArea     1460 non-null   int64
#  61  GarageQual     1379 non-null   str
#  62  GarageCond     1379 non-null   str
#  63  PavedDrive     1460 non-null   str
#  64  WoodDeckSF     1460 non-null   int64
#  65  OpenPorchSF    1460 non-null   int64
#  66  EnclosedPorch  1460 non-null   int64
#  67  3SsnPorch      1460 non-null   int64
#  68  ScreenPorch    1460 non-null   int64
#  69  PoolArea       1460 non-null   int64
#  70  MiscVal        1460 non-null   int64
#  71  MoSold         1460 non-null   int64
#  72  YrSold         1460 non-null   int64
#  73  SaleType       1460 non-null   str
#  74  SaleCondition  1460 non-null   str
#  75  SalePrice      1460 non-null   int64
#  76  SalePrice_log  1460 non-null   float64
# dtypes: float64(4), int64(35), str(38)
# memory usage: 878.4 KB

# %% [markdown]
# ## Filling Missing Values Of ["MasVnrArea", "MasVnrType"]
# ### The data showed in almost every record MasVnrType is NaN where Area is 0.0. So, converted that to NA rather than and where MasVnrArea was NaN we considered them as 0.0 because their MasVnrType was NaN. there were three records where MasVnrArea > 0 and MasVnrType was NaN so we filled them with mode of MasVnrType because not able to see any pattern

# %%
train_data.loc[
    (train_data["MasVnrArea"] == 0) & 
    (train_data["MasVnrType"].notna()),
    ["MasVnrArea", "MasVnrType"]
]
# Out:
#       MasVnrArea MasVnrType
# 688          0.0    BrkFace
# 1241         0.0      Stone

# %%
print((train_data["MasVnrArea"] == 0).sum())
print((train_data["MasVnrType"].isna()).sum())
print((
    (train_data["MasVnrArea"] == 0) &
    (train_data["MasVnrType"].isna())
).sum())
# Out:
# 861
# 872
# 859

# %%
problem_rows = train_data.loc[
    (train_data["MasVnrType"].isna()) &
    (train_data["MasVnrArea"].notna()) &
    (train_data["MasVnrArea"] != 0),
    ["MasVnrArea", "MasVnrType"]
]

problem_rows
# Out:
#       MasVnrArea MasVnrType
# 624        288.0        NaN
# 773          1.0        NaN
# 1230         1.0        NaN
# 1300       344.0        NaN
# 1334       312.0        NaN

# %%
train_data.loc[
    train_data["MasVnrArea"] == 1.0,
    "MasVnrArea"
] = 0.0

train_data.loc[
    train_data["MasVnrArea"] == 0,
    "MasVnrType"
] = "NA"

# %%
print((train_data["MasVnrArea"] == 0).sum())
print((train_data["MasVnrType"] == "NA").sum())
print((
    (train_data["MasVnrArea"] == 0) &
    (train_data["MasVnrType"]  == "NA")
).sum())
# Out:
# 863
# 863
# 863

# %%
problem_rows = train_data.loc[
    (train_data["MasVnrType"].isna()) &
    (train_data["MasVnrArea"] != 0),
    ["MasVnrArea", "MasVnrType"]
]

problem_rows
# Out:
#       MasVnrArea MasVnrType
# 234          NaN        NaN
# 529          NaN        NaN
# 624        288.0        NaN
# 650          NaN        NaN
# 936          NaN        NaN
# 973          NaN        NaN
# 977          NaN        NaN
# 1243         NaN        NaN
# 1278         NaN        NaN
# 1300       344.0        NaN
# 1334       312.0        NaN

# %%
# Making MasVnrArea from NaN to 0 where MasVnrType is NaN
mask_both_nan = (
    train_data["MasVnrArea"].isna() &
    train_data["MasVnrType"].isna()
)

train_data.loc[mask_both_nan, "MasVnrArea"] = 0
train_data.loc[mask_both_nan, "MasVnrType"] = "NA"

# %%
problem_rows = train_data.loc[
    (train_data["MasVnrType"].isna()) &
    (train_data["MasVnrArea"] != 0),
    ["MasVnrArea", "MasVnrType"]
]

problem_rows
# Out:
#       MasVnrArea MasVnrType
# 624        288.0        NaN
# 1300       344.0        NaN
# 1334       312.0        NaN

# %%
train_data.groupby("MasVnrType")["MasVnrArea"].describe()
# Out:
#             count        mean         std   min     25%    50%    75%     max
# MasVnrType
# BrkCmn       15.0  247.666667  182.423239  41.0   91.50  192.0  381.5   621.0
# BrkFace     444.0  259.592342  215.027938  11.0  114.75  202.5  336.0  1600.0
# NA          871.0    0.000000    0.000000   0.0    0.00    0.0    0.0     0.0
# Stone       127.0  241.188976  171.480469  16.0  114.50  208.0  297.5   860.0

# %%
import matplotlib.pyplot as plt

# Exclude NA veneer type
plot_data = train_data[train_data["MasVnrType"] != "NA"]

plt.figure(figsize=(8,5))
plot_data.boxplot(column="MasVnrArea", by="MasVnrType")

plt.title("MasVnrArea Distribution by MasVnrType")
plt.suptitle("")
plt.xlabel("MasVnrType")
plt.ylabel("MasVnrArea")

plt.show()

# %%
# Filling the MasVnrType NaN with mode where Area is greater
mask = (
    train_data["MasVnrType"].isna() &
    (train_data["MasVnrArea"] > 0)
)

train_data.loc[mask, "MasVnrType"] = "BrkFace"

# %%
train_data["MasVnrType"].value_counts()
# Out:
# MasVnrType
# NA         871
# BrkFace    447
# Stone      127
# BrkCmn      15
# Name: count, dtype: int64

# %%
print((train_data["MasVnrArea"].isna()).sum())
print((train_data["MasVnrType"].isna()).sum())
# Out:
# 0
# 0

# %% [markdown]
# ## Filling NaN For BsmtQual, BsmtCond, BsmtFinType1, BsmtExposure, BsmtFinType2
# ### We are filling these to NA since all of their TotalBsmtSF is equal to 0 meaning there is no Qual, Cond, etc. Other than that there are two records where BsmtExposure, BsmtFinType2 are one separately.
# ### For BsmtFinType2 we are setting up as Unf based on BsmtExposure and Viceversa

# %%
cols = [
    "BsmtQual",
    "BsmtCond",
    "BsmtFinType1",
    "BsmtExposure",
    "BsmtFinType2"
]

print(train_data[cols].isna().sum())

print((
    train_data[cols]
    .isna()
    .all(axis=1)
).sum())
# Out:
# BsmtQual        37
# BsmtCond        37
# BsmtFinType1    37
# BsmtExposure    38
# BsmtFinType2    38
# dtype: int64
# 37

# %%
len(train_data[train_data["TotalBsmtSF"] == 0])
# Out:
# 37

# %%
train_data[train_data["TotalBsmtSF"] == 0]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 17      18          90       RL        72.00    10791   Pave      Reg
# 39      40          90       RL        65.00     6040   Pave      Reg
# 90      91          20       RL        60.00     7200   Pave      Reg
# 102    103          90       RL        64.00     7018   Pave      Reg
# 156    157          20       RL        60.00     7200   Pave      Reg
# 182    183          20       RL        60.00     9060   Pave      Reg
# 259    260          20       RM        70.00    12702   Pave      Reg
# 342    343          90       RL        72.00     8544   Pave      Reg
# 362    363          85       RL        64.00     7301   Pave      Reg
# 371    372          50       RL        80.00    17120   Pave      Reg
# 392    393          20       RL        75.50     8339   Pave      IR1
# 520    521         190       RL        60.00    10800   Pave      Reg
# 532    533          20       RL        60.00     7200   Pave      Reg
# 533    534          20       RL        50.00     5000   Pave      Reg
# 553    554          20       RL        67.00     8777   Pave      Reg
# 646    647          20       RL        60.00     7200   Pave      Reg
# 705    706         190       RM        70.00     5600   Pave      Reg
# 736    737          90       RL        60.00     8544   Pave      Reg
# 749    750          50       RL        50.00     8405   Pave      Reg
# 778    779          90       RH        60.00     8400   Pave      Reg
# 868    869          60       RL        65.00    14762   Pave      IR2
# 894    895          90       RL        64.00     7018   Pave      Reg
# 897    898          90       RL        64.00     7018   Pave      Reg
# 984    985          90       RL        75.00    10125   Pave      Reg
# 1000  1001          20       RL        74.00    10206   Pave      Reg
# 1011  1012          90       RL        75.00     9825   Pave      Reg
# 1035  1036          20       RL        72.12    11500   Pave      IR1
# 1045  1046          20       RL        72.12    13680   Pave      IR1
# 1048  1049          20       RL       100.00    21750   Pave      Reg
# 1049  1050          20       RL        60.00    11100   Pave      Reg
# 1090  1091          90       RL        60.00     8544   Pave      Reg
# 1179  1180          20       RL        77.00     8335   Pave      Reg
# 1216  1217          90       RM        68.00     8930   Pave      Reg
# 1218  1219          50       RM        52.00     6240   Pave      Reg
# 1232  1233          90       RL        70.00     9842   Pave      Reg
# 1321  1322          20       RL        58.00     6627   Pave      IR1
# 1412  1413          90       RL        60.00     7200   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 17           Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 39           Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 90           Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 102          Bnk    AllPub    Inside       Gtl      SawyerW       Norm
# 156          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 182          Lvl    AllPub    Inside       Gtl      Edwards     Artery
# 259          Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 342          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 362          Lvl    AllPub    Corner       Gtl      Edwards       Norm
# 371          Lvl    AllPub    Inside       Gtl      ClearCr      Feedr
# 392          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 520          Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 532          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 533          Low    AllPub    Inside       Mod      BrkSide       Norm
# 553          Lvl    AllPub    Inside       Gtl      Edwards      Feedr
# 646          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 705          Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
# 736          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 749          Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 778          Lvl    AllPub    Inside       Gtl      SawyerW      Feedr
# 868          Lvl    AllPub    Corner       Gtl      Gilbert      Feedr
# 894          Bnk    AllPub    Inside       Gtl      SawyerW       Norm
# 897          Lvl    AllPub    Inside       Gtl      SawyerW      Feedr
# 984          Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1000         Lvl    AllPub    Corner       Gtl      Edwards       Norm
# 1011         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 1035         Lvl    AllPub   CulDSac       Gtl      Edwards       Norm
# 1045         Lvl    AllPub   CulDSac       Gtl      Edwards       Norm
# 1048         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1049         Low    AllPub    Inside       Gtl      Edwards       Norm
# 1090         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 1179         Lvl    AllPub    Corner       Gtl      Edwards       Norm
# 1216         Lvl    AllPub    Inside       Gtl       Sawyer       RRAe
# 1218         Lvl    AllPub    Inside       Gtl      BrkSide       Norm
# 1232         Lvl    AllPub       FR2       Gtl        NAmes       Norm
# 1321         Lvl    AllPub    Corner       Gtl      BrkSide      Feedr
# 1412         Lvl    AllPub    Inside       Gtl        NAmes       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 17         Norm   Duplex     1Story            4            5       1967
# 39         Norm   Duplex     1Story            4            5       1955
# 90         Norm     1Fam     1Story            4            5       1950
# 102        Norm   Duplex     1Story            5            5       1979
# 156        Norm     1Fam     1Story            5            7       1950
# 182        Norm     1Fam     1Story            5            6       1957
# 259        Norm     1Fam     1Story            5            5       1956
# 342        Norm   Duplex     1Story            3            4       1949
# 362        Norm     1Fam     SFoyer            7            5       2003
# 371        Norm     1Fam     1.5Fin            4            4       1959
# 392        Norm     1Fam     1Story            5            7       1959
# 520        Norm   2fmCon     2Story            4            7       1900
# 532        Norm     1Fam     1Story            5            7       1955
# 533        Norm     1Fam     1Story            1            3       1946
# 553        Norm     1Fam     1Story            4            5       1949
# 646        Norm     1Fam     1Story            5            5       1950
# 705        Norm   2fmCon     2Story            4            5       1930
# 736        Norm   Duplex     1Story            3            4       1950
# 749        Norm     1Fam     1.5Fin            4            3       1945
# 778        Norm   Duplex     1Story            5            5       1977
# 868        Norm     1Fam     2Story            5            6       1948
# 894        Norm   Duplex     1Story            5            5       1979
# 897        Norm   Duplex     2Story            5            5       1979
# 984        Norm   Duplex     1.5Fin            5            5       1977
# 1000       Norm     1Fam     1Story            3            3       1952
# 1011       Norm   Duplex     1Story            5            5       1965
# 1035       Norm     1Fam     1Story            4            3       1957
# 1045       Norm     1Fam     1Story            3            5       1955
# 1048       Norm     1Fam     1Story            5            4       1960
# 1049       Norm     1Fam     1Story            4            7       1946
# 1090       Norm   Duplex     1Story            3            4       1950
# 1179       Norm     1Fam     1Story            5            5       1954
# 1216       Norm   Duplex     1.5Fin            6            5       1978
# 1218       Norm     1Fam     1.5Fin            4            5       1947
# 1232       Norm   Duplex     1Story            4            5       1962
# 1321       Norm     1Fam     1Story            3            6       1949
# 1412       Norm   Duplex     1Story            4            5       1949
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 17            1967     Gable  CompShg     MetalSd     MetalSd         NA
# 39            1955     Gable  CompShg     AsbShng     Plywood         NA
# 90            1950     Gable  CompShg     BrkFace     Wd Sdng         NA
# 102           1979     Gable  CompShg     HdBoard     HdBoard         NA
# 156           1950       Hip  CompShg     Wd Sdng     Wd Sdng         NA
# 182           2006       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 259           1956     Gable  CompShg     BrkFace     BrkFace         NA
# 342           1950     Gable  CompShg      Stucco      Stucco    BrkFace
# 362           2003     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 371           1959     Gable  CompShg     WdShing     Plywood         NA
# 392           1959     Gable  CompShg     MetalSd     MetalSd         NA
# 520           2000     Gable  CompShg     MetalSd     MetalSd         NA
# 532           2007     Gable  CompShg     VinylSd     VinylSd         NA
# 533           1950     Gable  CompShg     VinylSd     VinylSd         NA
# 553           2003     Gable  CompShg     VinylSd     VinylSd         NA
# 646           1950       Hip  CompShg     MetalSd     MetalSd         NA
# 705           1950       Hip  CompShg     VinylSd     Wd Shng         NA
# 736           1950     Gable  CompShg      Stucco       Stone         NA
# 749           1950     Gable  CompShg     WdShing     Wd Shng         NA
# 778           1977     Gable  CompShg     Plywood     Plywood    BrkFace
# 868           1950     Gable  CompShg     Plywood     Plywood         NA
# 894           1979     Gable  CompShg     Plywood     Plywood         NA
# 897           1979     Gable  CompShg     Plywood     Plywood         NA
# 984           1977     Gable  CompShg     Plywood     Plywood         NA
# 1000          1952      Flat  Tar&Grv     BrkComm     Brk Cmn         NA
# 1011          1965       Hip  CompShg     AsphShn     AsphShn         NA
# 1035          1957     Gable  CompShg     Wd Sdng     Wd Sdng         NA
# 1045          1955       Hip  CompShg     BrkFace     Wd Sdng         NA
# 1048          2006       Hip  CompShg     HdBoard     HdBoard    BrkFace
# 1049          2006     Gable  CompShg     MetalSd     MetalSd         NA
# 1090          1950     Gable  CompShg     BrkFace     BrkFace         NA
# 1179          1954     Gable  CompShg     Wd Sdng     Wd Sdng         NA
# 1216          1978     Gable  CompShg     VinylSd     VinylSd         NA
# 1218          1950     Gable  CompShg     AsbShng     AsbShng         NA
# 1232          1962     Gable  CompShg     HdBoard     HdBoard         NA
# 1321          1950       Hip  CompShg     VinylSd     VinylSd         NA
# 1412          1950     Gable  CompShg     BrkFace       Stone         NA
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 17           0.0        TA        TA       Slab      NaN      NaN
# 39           0.0        TA        TA      PConc      NaN      NaN
# 90           0.0        TA        TA       Slab      NaN      NaN
# 102          0.0        TA        Fa       Slab      NaN      NaN
# 156          0.0        TA        TA     CBlock      NaN      NaN
# 182         98.0        TA        TA      PConc      NaN      NaN
# 259          0.0        TA        TA      PConc      NaN      NaN
# 342        340.0        TA        TA       Slab      NaN      NaN
# 362        500.0        Gd        TA       Slab      NaN      NaN
# 371          0.0        TA        TA     CBlock      NaN      NaN
# 392          0.0        TA        TA       Slab      NaN      NaN
# 520          0.0        TA        TA     BrkTil      NaN      NaN
# 532          0.0        TA        TA       Slab      NaN      NaN
# 533          0.0        Fa        Fa       Slab      NaN      NaN
# 553          0.0        TA        TA     CBlock      NaN      NaN
# 646          0.0        TA        TA     CBlock      NaN      NaN
# 705          0.0        Fa        Fa       Slab      NaN      NaN
# 736          0.0        TA        TA     CBlock      NaN      NaN
# 749          0.0        TA        TA       Slab      NaN      NaN
# 778        320.0        TA        TA       Slab      NaN      NaN
# 868          0.0        TA        TA       Slab      NaN      NaN
# 894          0.0        TA        TA       Slab      NaN      NaN
# 897          0.0        TA        TA       Slab      NaN      NaN
# 984          0.0        TA        TA     CBlock      NaN      NaN
# 1000         0.0        TA        TA       Slab      NaN      NaN
# 1011         0.0        TA        TA     CBlock      NaN      NaN
# 1035         0.0        TA        Gd       Slab      NaN      NaN
# 1045         0.0        TA        TA       Slab      NaN      NaN
# 1048        75.0        TA        Fa       Slab      NaN      NaN
# 1049         0.0        TA        TA     CBlock      NaN      NaN
# 1090         0.0        TA        TA       Slab      NaN      NaN
# 1179         0.0        TA        TA       Slab      NaN      NaN
# 1216         0.0        TA        TA       Slab      NaN      NaN
# 1218         0.0        TA        TA       Slab      NaN      NaN
# 1232         0.0        TA        TA       Slab      NaN      NaN
# 1321         0.0        TA        TA     CBlock      NaN      NaN
# 1412         0.0        TA        TA       Slab      NaN      NaN
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 17            NaN          NaN           0          NaN           0
# 39            NaN          NaN           0          NaN           0
# 90            NaN          NaN           0          NaN           0
# 102           NaN          NaN           0          NaN           0
# 156           NaN          NaN           0          NaN           0
# 182           NaN          NaN           0          NaN           0
# 259           NaN          NaN           0          NaN           0
# 342           NaN          NaN           0          NaN           0
# 362           NaN          NaN           0          NaN           0
# 371           NaN          NaN           0          NaN           0
# 392           NaN          NaN           0          NaN           0
# 520           NaN          NaN           0          NaN           0
# 532           NaN          NaN           0          NaN           0
# 533           NaN          NaN           0          NaN           0
# 553           NaN          NaN           0          NaN           0
# 646           NaN          NaN           0          NaN           0
# 705           NaN          NaN           0          NaN           0
# 736           NaN          NaN           0          NaN           0
# 749           NaN          NaN           0          NaN           0
# 778           NaN          NaN           0          NaN           0
# 868           NaN          NaN           0          NaN           0
# 894           NaN          NaN           0          NaN           0
# 897           NaN          NaN           0          NaN           0
# 984           NaN          NaN           0          NaN           0
# 1000          NaN          NaN           0          NaN           0
# 1011          NaN          NaN           0          NaN           0
# 1035          NaN          NaN           0          NaN           0
# 1045          NaN          NaN           0          NaN           0
# 1048          NaN          NaN           0          NaN           0
# 1049          NaN          NaN           0          NaN           0
# 1090          NaN          NaN           0          NaN           0
# 1179          NaN          NaN           0          NaN           0
# 1216          NaN          NaN           0          NaN           0
# 1218          NaN          NaN           0          NaN           0
# 1232          NaN          NaN           0          NaN           0
# 1321          NaN          NaN           0          NaN           0
# 1412          NaN          NaN           0          NaN           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 17            0            0    GasA        TA          Y      SBrkr
# 39            0            0    GasA        TA          N      FuseP
# 90            0            0    GasA        TA          Y      FuseA
# 102           0            0    GasA        TA          Y      SBrkr
# 156           0            0    GasA        TA          Y      FuseF
# 182           0            0    GasA        Ex          Y      SBrkr
# 259           0            0    GasA        Gd          Y      FuseA
# 342           0            0    Wall        Fa          N      FuseA
# 362           0            0    GasA        Ex          Y      SBrkr
# 371           0            0    GasA        TA          Y      SBrkr
# 392           0            0    GasA        TA          Y      SBrkr
# 520           0            0    GasA        TA          N      FuseA
# 532           0            0    GasA        Ex          Y      SBrkr
# 533           0            0    GasA        Fa          N      FuseF
# 553           0            0    GasA        Ex          Y      SBrkr
# 646           0            0    GasA        Gd          Y      SBrkr
# 705           0            0    GasA        Fa          N      SBrkr
# 736           0            0    GasA        Gd          N      FuseF
# 749           0            0    Wall        TA          N      FuseF
# 778           0            0    GasA        TA          Y      SBrkr
# 868           0            0    GasA        Gd          Y      SBrkr
# 894           0            0    GasA        TA          Y      SBrkr
# 897           0            0    GasA        TA          Y      SBrkr
# 984           0            0    GasA        TA          Y      SBrkr
# 1000          0            0    GasW        Fa          N      FuseF
# 1011          0            0    GasA        TA          N      SBrkr
# 1035          0            0    GasA        Ex          N      SBrkr
# 1045          0            0    GasA        Ex          Y      FuseA
# 1048          0            0    GasA        TA          Y      SBrkr
# 1049          0            0    GasA        Ex          Y      SBrkr
# 1090          0            0    Wall        Fa          N      FuseA
# 1179          0            0    GasA        Gd          Y      SBrkr
# 1216          0            0    GasA        TA          Y      SBrkr
# 1218          0            0    GasA        Gd          N      SBrkr
# 1232          0            0    GasA        TA          Y      SBrkr
# 1321          0            0   Floor        TA          N      SBrkr
# 1412          0            0    Wall        Fa          N      FuseF
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 17        1296         0             0       1296             0             0
# 39        1152         0             0       1152             0             0
# 90        1040         0             0       1040             0             0
# 102       1535         0             0       1535             0             0
# 156       1040         0             0       1040             0             0
# 182       1340         0             0       1340             0             0
# 259        882         0             0        882             0             0
# 342       1040         0             0       1040             0             0
# 362        495      1427             0       1922             0             0
# 371       1120       468             0       1588             0             0
# 392        882         0             0        882             0             0
# 520        694       600             0       1294             0             0
# 532        827         0             0        827             0             0
# 533        334         0             0        334             0             0
# 553       1126         0             0       1126             0             0
# 646       1048         0             0       1048             0             0
# 705        372       720             0       1092             0             0
# 736       1040         0             0       1040             0             0
# 749       1088       441             0       1529             0             0
# 778       2020         0             0       2020             0             0
# 868       1547       720            53       2320             0             0
# 894       1535         0             0       1535             0             0
# 897       1120      1120             0       2240             0             0
# 984       1302       432             0       1734             0             0
# 1000       944         0             0        944             0             0
# 1011      1664         0             0       1664             0             0
# 1035       845         0             0        845             0             0
# 1045      1733         0             0       1733             0             0
# 1048      1771         0             0       1771             0             0
# 1049       930         0             0        930             0             0
# 1090      1040         0             0       1040             0             0
# 1179      1124         0             0       1124             0             0
# 1216      1318       584             0       1902             0             0
# 1218       672       240             0        912             0             0
# 1232      1224         0             0       1224             0             0
# 1321       720         0             0        720             0             0
# 1412      1040         0             0       1040             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 17           2         0             2             2          TA
# 39           2         0             2             2          Fa
# 90           1         0             2             1          TA
# 102          2         0             4             2          TA
# 156          1         0             2             1          TA
# 182          1         0             3             1          TA
# 259          1         0             2             1          TA
# 342          2         0             2             2          TA
# 362          3         0             4             1          Gd
# 371          2         0             4             1          TA
# 392          1         0             3             1          TA
# 520          2         0             3             2          TA
# 532          1         0             2             1          TA
# 533          1         0             1             1          Fa
# 553          2         0             2             1          Gd
# 646          1         0             3             1          TA
# 705          2         0             3             2          Fa
# 736          2         0             2             2          TA
# 749          2         0             4             1          TA
# 778          2         0             4             2          TA
# 868          2         0             2             1          TA
# 894          2         0             4             2          TA
# 897          2         0             6             2          TA
# 984          2         0             4             2          Gd
# 1000         1         0             2             1          Fa
# 1011         2         0             4             2          TA
# 1035         1         0             3             1          TA
# 1045         2         0             4             1          TA
# 1048         1         0             3             1          TA
# 1049         1         0             2             1          Gd
# 1090         2         0             2             2          TA
# 1179         1         0             3             1          TA
# 1216         2         0             4             2          TA
# 1218         1         0             2             1          TA
# 1232         2         0             2             2          TA
# 1321         1         0             2             1          TA
# 1412         2         0             2             2          TA
#
#       TotRmsAbvGrd Functional  Fireplaces GarageType  GarageYrBlt  \
# 17               6        Typ           0    CarPort       1967.0
# 39               6        Typ           0        NaN          NaN
# 90               4        Typ           0     Detchd       1950.0
# 102              8        Typ           0     Attchd       1979.0
# 156              5        Typ           0     Detchd       1950.0
# 182              7        Typ           1     Attchd       1957.0
# 259              4        Typ           0     Detchd       1956.0
# 342              6        Typ           0     Detchd       1949.0
# 362              7        Typ           1    BuiltIn       2003.0
# 371              7       Min2           1     Detchd       1991.0
# 392              5        Typ           0     Attchd       1959.0
# 520              7        Typ           0        NaN          NaN
# 532              5        Mod           1     Detchd       1967.0
# 533              2        Typ           0        NaN          NaN
# 553              5        Typ           0     Detchd       2002.0
# 646              7       Min1           0     Detchd       1950.0
# 705              7        Mod           0        NaN          NaN
# 736              6        Typ           0     Detchd       1949.0
# 749              9        Mod           0     Detchd       1945.0
# 778             10        Typ           2     Detchd       1977.0
# 868              7        Typ           1     Attchd       1979.0
# 894              8        Typ           0     Attchd       1979.0
# 897             12        Typ           0     Detchd       1979.0
# 984              8        Typ           0     Attchd       1977.0
# 1000             4       Min1           0     Detchd       1956.0
# 1011             8        Typ           0        NaN          NaN
# 1035             5        Typ           0     Detchd       1957.0
# 1045             8       Min2           1     Attchd       1955.0
# 1048             9       Min1           1     Attchd       1960.0
# 1049             6        Typ           0     Detchd       1946.0
# 1090             6        Typ           0     Detchd       1987.0
# 1179             5       Min2           1        NaN          NaN
# 1216             8        Typ           0     Attchd       1978.0
# 1218             3        Typ           0        NaN          NaN
# 1232             6        Typ           0    CarPort       1962.0
# 1321             4        Typ           0     Detchd       1955.0
# 1412             6        Typ           0     Detchd       1956.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 17            Unf           2         516         TA         TA          Y
# 39            NaN           0           0        NaN        NaN          N
# 90            Unf           2         420         TA         TA          Y
# 102           Unf           2         410         TA         TA          Y
# 156           Unf           2         625         TA         TA          Y
# 182           RFn           1         252         TA         TA          Y
# 259           Unf           1         308         TA         TA          Y
# 342           Unf           2         400         TA         TA          Y
# 362           RFn           2         672         TA         TA          Y
# 371           Fin           2         680         TA         TA          N
# 392           RFn           1         294         TA         TA          Y
# 520           NaN           0           0        NaN        NaN          N
# 532           Unf           1         392         TA         TA          Y
# 533           NaN           0           0        NaN        NaN          N
# 553           Fin           2         520         TA         TA          N
# 646           Unf           2         420         TA         TA          Y
# 705           NaN           0           0        NaN        NaN          N
# 736           Unf           2         400         TA         TA          Y
# 749           Unf           1         240         TA         TA          N
# 778           Unf           2         630         TA         TA          Y
# 868           Unf           2         672         TA         TA          P
# 894           Unf           2         400         TA         TA          Y
# 897           Unf           2         528         TA         TA          Y
# 984           Unf           2         539         TA         TA          Y
# 1000          Unf           2         528         TA         Fa          Y
# 1011          NaN           0           0        NaN        NaN          Y
# 1035          Unf           1         290         TA         TA          N
# 1045          Unf           2         452         TA         TA          Y
# 1048          Unf           2         336         TA         TA          Y
# 1049          Unf           1         308         TA         TA          Y
# 1090          Unf           2         400         TA         TA          Y
# 1179          NaN           0           0        NaN        NaN          N
# 1216          Unf           2         539         TA         TA          Y
# 1218          NaN           0           0        NaN        NaN          N
# 1232          Unf           2         462         TA         TA          Y
# 1321          Unf           1         287         TA         Fa          Y
# 1412          Unf           2         420         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 17             0            0              0          0            0
# 39             0            0              0          0            0
# 90             0           29              0          0            0
# 102            0            0              0          0            0
# 156            0            0              0          0            0
# 182          116            0              0        180            0
# 259            0           45              0          0            0
# 342            0            0              0          0            0
# 362            0            0            177          0            0
# 371            0           59              0          0            0
# 392            0            0              0          0            0
# 520          220          114            210          0            0
# 532            0            0              0          0            0
# 533            0            0              0          0            0
# 553            0           96              0          0            0
# 646            0           27              0          0            0
# 705            0            0              0          0            0
# 736            0            0              0          0            0
# 749           92            0            185          0            0
# 778            0            0              0          0            0
# 868          120          144              0          0            0
# 894            0            0              0          0            0
# 897          154            0              0          0            0
# 984            0            0              0          0            0
# 1000           0            0              0          0            0
# 1011           0            0              0          0            0
# 1035         186            0              0          0            0
# 1045           0            0              0          0            0
# 1048           0            0              0          0            0
# 1049           0            0              0          0            0
# 1090           0            0              0          0            0
# 1179           0           36            190          0            0
# 1216           0            0              0          0            0
# 1218           0            0              0          0            0
# 1232           0            0              0          0            0
# 1321           0            0              0          0            0
# 1412           0            0              0          0            0
#
#       PoolArea  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice  \
# 17           0      500      10    2006       WD        Normal      90000
# 39           0        0       6    2008       WD       AdjLand      82000
# 90           0        0       7    2006       WD        Normal     109900
# 102          0        0       6    2009       WD        Alloca     118964
# 156          0        0       6    2006       WD        Normal     109500
# 182          0        0       6    2007       WD        Normal     120000
# 259          0        0      12    2008       WD        Normal      97000
# 342          0        0       5    2006       WD        Normal      87500
# 362          0        0       7    2009    ConLD        Normal     198500
# 371          0        0       7    2008       WD        Normal     134432
# 392          0     1200       7    2007       WD        Normal     106500
# 520          0        0       8    2008       WD        Normal     106250
# 532          0        0       4    2010       WD        Normal     107500
# 533          0        0       1    2007       WD        Normal      39300
# 553          0        0       5    2009       WD        Normal     108000
# 646          0        0       7    2008       WD        Normal      98300
# 705          0     3500       7    2010       WD        Normal      55000
# 736          0        0       7    2006       WD        Normal      93500
# 749          0        0       4    2009       WD        Normal      98000
# 778          0        0      10    2007       WD        Normal     144000
# 868          0        0       5    2006       WD        Normal     169000
# 894          0        0       6    2009       WD        Alloca     118858
# 897          0        0       6    2009       WD        Alloca     142953
# 984          0        0       8    2009      COD        Normal     126000
# 1000         0        0       7    2009       WD        Normal      82000
# 1011         0        0       5    2010       WD        Normal     100000
# 1035         0        0       1    2009       WD        Normal      84000
# 1045         0        0       6    2009       WD        Normal     139600
# 1048         0        0      11    2009       WD        Normal     115000
# 1049         0        0       4    2010       WD       Abnorml      84900
# 1090         0        0       6    2009       WD        Normal      92900
# 1179         0        0       4    2006       WD        Normal      93000
# 1216         0        0       4    2010       WD        Normal     112000
# 1218         0        0       7    2006       WD        Normal      80500
# 1232         0        0       3    2007       WD        Normal     101800
# 1321         0        0       7    2008       WD        Normal      72500
# 1412         0        0       6    2009       WD        Normal      90000
#
#       SalePrice_log
# 17        11.407576
# 39        11.314487
# 90        11.607335
# 102       11.686585
# 156       11.603689
# 182       11.695255
# 259       11.482477
# 342       11.379406
# 362       12.198549
# 371       11.808821
# 392       11.575910
# 520       11.573559
# 532       11.585255
# 533       10.579005
# 553       11.589896
# 646       11.495789
# 705       10.915107
# 736       11.445727
# 749       11.492733
# 778       11.877576
# 868       12.037660
# 894       11.685693
# 897       11.870278
# 984       11.744045
# 1000      11.314487
# 1011      11.512935
# 1035      11.338584
# 1045      11.846544
# 1048      11.652696
# 1049      11.349241
# 1090      11.439290
# 1179      11.440366
# 1216      11.626263
# 1218      11.296025
# 1232      11.530775
# 1321      11.191356
# 1412      11.407576

# %%
cols = [
    "BsmtQual",
    "BsmtCond",
    "BsmtFinType1",
    "BsmtExposure",
    "BsmtFinType2"
]

mask_no_bsmt = train_data["TotalBsmtSF"] == 0

train_data.loc[mask_no_bsmt, cols] = "NA"

# %%
train_data.loc[
    (train_data["BsmtExposure"].isna()) &
    (train_data["TotalBsmtSF"] > 0),
    ["TotalBsmtSF", "BsmtQual", "BsmtCond", 
     "BsmtFinType1", "BsmtExposure", "BsmtFinType2"]
]
# Out:
#      TotalBsmtSF BsmtQual BsmtCond BsmtFinType1 BsmtExposure BsmtFinType2
# 948          936       Gd       TA          Unf          NaN          Unf

# %%
train_data.loc[
    (train_data["BsmtFinType2"].isna()) &
    (train_data["TotalBsmtSF"] > 0),
    ["TotalBsmtSF", "BsmtQual", "BsmtCond", 
     "BsmtFinType1", "BsmtExposure", "BsmtFinType2"]
]
# Out:
#      TotalBsmtSF BsmtQual BsmtCond BsmtFinType1 BsmtExposure BsmtFinType2
# 332         3206       Gd       TA          GLQ           No          NaN

# %%
train_data.loc[
    train_data["BsmtExposure"] == "No"
].groupby("BsmtFinType2").size()
# Out:
# BsmtFinType2
# ALQ      3
# BLQ     25
# GLQ      7
# LwQ     31
# Rec     36
# Unf    850
# dtype: int64

# %%
train_data.loc[
    train_data["BsmtFinType2"].isna(),
    "BsmtFinType2"
] = "Unf"

# %%
train_data.loc[
    train_data["BsmtFinType2"] == "Unf"
].groupby("BsmtExposure").size()
# Out:
# BsmtExposure
# Av    196
# Gd    113
# Mn     96
# No    851
# dtype: int64

# %%
train_data.loc[
    train_data["BsmtExposure"].isna(),
    "BsmtExposure"
] = "No"

# %% [markdown]
# ### Filled Electrical with SBrkr as it is dominant accorss CentralAir Y and separately as well

# %%
train_data[train_data["Electrical"].isna()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 1379  1380          80       RL         73.0     9735   Pave      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1379         Lvl    AllPub    Inside       Gtl       Timber       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1379       Norm     1Fam       SLvl            5            5       2006
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1379          2007     Gable  CompShg     VinylSd     VinylSd         NA
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1379         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1379           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1379        384          384    GasA        Gd          Y        NaN
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1379       754       640             0       1394             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1379         2         1             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces GarageType  GarageYrBlt  \
# 1379             7        Typ           0    BuiltIn       2007.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1379          Fin           2         400         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1379         100            0              0          0            0
#
#       PoolArea  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice  \
# 1379         0        0       5    2008       WD        Normal     167500
#
#       SalePrice_log
# 1379      12.028745

# %%
# train_data.groupby("Electrical").size()
train_data.loc[
    train_data["CentralAir"] == "Y"
].groupby("Electrical").size()
# Out:
# Electrical
# FuseA      72
# FuseF       9
# Mix         1
# SBrkr    1282
# dtype: int64

# %%
train_data.loc[
    train_data["Electrical"].isna(),
    "Electrical"
] = "SBrkr"

# %% [markdown]
# ## Filing NaN values for GarageType, GarageYrBlt, GarageFinish, GarageQual, GarageCond
# ### We filled them with NA as GarageArea for them is 0 which states they should be NA and year built should be 0

# %%
garage_cols = [
    "GarageType",
    "GarageYrBlt",
    "GarageFinish",
    "GarageQual",
    "GarageCond"
]

train_data.loc[
    train_data[garage_cols].isna().all(axis=1),
    garage_cols + ["GarageCars", "GarageArea"]
]
# Out:
#      GarageType  GarageYrBlt GarageFinish GarageQual GarageCond  GarageCars  \
# 39          NaN          NaN          NaN        NaN        NaN           0
# 48          NaN          NaN          NaN        NaN        NaN           0
# 78          NaN          NaN          NaN        NaN        NaN           0
# 88          NaN          NaN          NaN        NaN        NaN           0
# 89          NaN          NaN          NaN        NaN        NaN           0
# 99          NaN          NaN          NaN        NaN        NaN           0
# 108         NaN          NaN          NaN        NaN        NaN           0
# 125         NaN          NaN          NaN        NaN        NaN           0
# 127         NaN          NaN          NaN        NaN        NaN           0
# 140         NaN          NaN          NaN        NaN        NaN           0
# 148         NaN          NaN          NaN        NaN        NaN           0
# 155         NaN          NaN          NaN        NaN        NaN           0
# 163         NaN          NaN          NaN        NaN        NaN           0
# 165         NaN          NaN          NaN        NaN        NaN           0
# 198         NaN          NaN          NaN        NaN        NaN           0
# 210         NaN          NaN          NaN        NaN        NaN           0
# 241         NaN          NaN          NaN        NaN        NaN           0
# 250         NaN          NaN          NaN        NaN        NaN           0
# 287         NaN          NaN          NaN        NaN        NaN           0
# 291         NaN          NaN          NaN        NaN        NaN           0
# 307         NaN          NaN          NaN        NaN        NaN           0
# 375         NaN          NaN          NaN        NaN        NaN           0
# 386         NaN          NaN          NaN        NaN        NaN           0
# 393         NaN          NaN          NaN        NaN        NaN           0
# 431         NaN          NaN          NaN        NaN        NaN           0
# 434         NaN          NaN          NaN        NaN        NaN           0
# 441         NaN          NaN          NaN        NaN        NaN           0
# 464         NaN          NaN          NaN        NaN        NaN           0
# 495         NaN          NaN          NaN        NaN        NaN           0
# 520         NaN          NaN          NaN        NaN        NaN           0
# 528         NaN          NaN          NaN        NaN        NaN           0
# 533         NaN          NaN          NaN        NaN        NaN           0
# 535         NaN          NaN          NaN        NaN        NaN           0
# 562         NaN          NaN          NaN        NaN        NaN           0
# 582         NaN          NaN          NaN        NaN        NaN           0
# 613         NaN          NaN          NaN        NaN        NaN           0
# 614         NaN          NaN          NaN        NaN        NaN           0
# 620         NaN          NaN          NaN        NaN        NaN           0
# 635         NaN          NaN          NaN        NaN        NaN           0
# 636         NaN          NaN          NaN        NaN        NaN           0
# 638         NaN          NaN          NaN        NaN        NaN           0
# 649         NaN          NaN          NaN        NaN        NaN           0
# 705         NaN          NaN          NaN        NaN        NaN           0
# 710         NaN          NaN          NaN        NaN        NaN           0
# 738         NaN          NaN          NaN        NaN        NaN           0
# 750         NaN          NaN          NaN        NaN        NaN           0
# 784         NaN          NaN          NaN        NaN        NaN           0
# 826         NaN          NaN          NaN        NaN        NaN           0
# 843         NaN          NaN          NaN        NaN        NaN           0
# 921         NaN          NaN          NaN        NaN        NaN           0
# 942         NaN          NaN          NaN        NaN        NaN           0
# 954         NaN          NaN          NaN        NaN        NaN           0
# 960         NaN          NaN          NaN        NaN        NaN           0
# 968         NaN          NaN          NaN        NaN        NaN           0
# 970         NaN          NaN          NaN        NaN        NaN           0
# 976         NaN          NaN          NaN        NaN        NaN           0
# 1009        NaN          NaN          NaN        NaN        NaN           0
# 1011        NaN          NaN          NaN        NaN        NaN           0
# 1030        NaN          NaN          NaN        NaN        NaN           0
# 1038        NaN          NaN          NaN        NaN        NaN           0
# 1096        NaN          NaN          NaN        NaN        NaN           0
# 1123        NaN          NaN          NaN        NaN        NaN           0
# 1131        NaN          NaN          NaN        NaN        NaN           0
# 1137        NaN          NaN          NaN        NaN        NaN           0
# 1143        NaN          NaN          NaN        NaN        NaN           0
# 1173        NaN          NaN          NaN        NaN        NaN           0
# 1179        NaN          NaN          NaN        NaN        NaN           0
# 1218        NaN          NaN          NaN        NaN        NaN           0
# 1219        NaN          NaN          NaN        NaN        NaN           0
# 1234        NaN          NaN          NaN        NaN        NaN           0
# 1257        NaN          NaN          NaN        NaN        NaN           0
# 1283        NaN          NaN          NaN        NaN        NaN           0
# 1323        NaN          NaN          NaN        NaN        NaN           0
# 1325        NaN          NaN          NaN        NaN        NaN           0
# 1326        NaN          NaN          NaN        NaN        NaN           0
# 1337        NaN          NaN          NaN        NaN        NaN           0
# 1349        NaN          NaN          NaN        NaN        NaN           0
# 1407        NaN          NaN          NaN        NaN        NaN           0
# 1449        NaN          NaN          NaN        NaN        NaN           0
# 1450        NaN          NaN          NaN        NaN        NaN           0
# 1453        NaN          NaN          NaN        NaN        NaN           0
#
#       GarageArea
# 39             0
# 48             0
# 78             0
# 88             0
# 89             0
# 99             0
# 108            0
# 125            0
# 127            0
# 140            0
# 148            0
# 155            0
# 163            0
# 165            0
# 198            0
# 210            0
# 241            0
# 250            0
# 287            0
# 291            0
# 307            0
# 375            0
# 386            0
# 393            0
# 431            0
# 434            0
# 441            0
# 464            0
# 495            0
# 520            0
# 528            0
# 533            0
# 535            0
# 562            0
# 582            0
# 613            0
# 614            0
# 620            0
# 635            0
# 636            0
# 638            0
# 649            0
# 705            0
# 710            0
# 738            0
# 750            0
# 784            0
# 826            0
# 843            0
# 921            0
# 942            0
# 954            0
# 960            0
# 968            0
# 970            0
# 976            0
# 1009           0
# 1011           0
# 1030           0
# 1038           0
# 1096           0
# 1123           0
# 1131           0
# 1137           0
# 1143           0
# 1173           0
# 1179           0
# 1218           0
# 1219           0
# 1234           0
# 1257           0
# 1283           0
# 1323           0
# 1325           0
# 1326           0
# 1337           0
# 1349           0
# 1407           0
# 1449           0
# 1450           0
# 1453           0

# %%
train_data.loc[
    (train_data["GarageCars"] == 0) | 
    (train_data["GarageArea"] == 0),
    ["GarageCars", "GarageArea", 
     "GarageType", "GarageFinish", 
     "GarageQual", "GarageCond", "GarageYrBlt"]
]
# Out:
#       GarageCars  GarageArea GarageType GarageFinish GarageQual GarageCond  \
# 39             0           0        NaN          NaN        NaN        NaN
# 48             0           0        NaN          NaN        NaN        NaN
# 78             0           0        NaN          NaN        NaN        NaN
# 88             0           0        NaN          NaN        NaN        NaN
# 89             0           0        NaN          NaN        NaN        NaN
# 99             0           0        NaN          NaN        NaN        NaN
# 108            0           0        NaN          NaN        NaN        NaN
# 125            0           0        NaN          NaN        NaN        NaN
# 127            0           0        NaN          NaN        NaN        NaN
# 140            0           0        NaN          NaN        NaN        NaN
# 148            0           0        NaN          NaN        NaN        NaN
# 155            0           0        NaN          NaN        NaN        NaN
# 163            0           0        NaN          NaN        NaN        NaN
# 165            0           0        NaN          NaN        NaN        NaN
# 198            0           0        NaN          NaN        NaN        NaN
# 210            0           0        NaN          NaN        NaN        NaN
# 241            0           0        NaN          NaN        NaN        NaN
# 250            0           0        NaN          NaN        NaN        NaN
# 287            0           0        NaN          NaN        NaN        NaN
# 291            0           0        NaN          NaN        NaN        NaN
# 307            0           0        NaN          NaN        NaN        NaN
# 375            0           0        NaN          NaN        NaN        NaN
# 386            0           0        NaN          NaN        NaN        NaN
# 393            0           0        NaN          NaN        NaN        NaN
# 431            0           0        NaN          NaN        NaN        NaN
# 434            0           0        NaN          NaN        NaN        NaN
# 441            0           0        NaN          NaN        NaN        NaN
# 464            0           0        NaN          NaN        NaN        NaN
# 495            0           0        NaN          NaN        NaN        NaN
# 520            0           0        NaN          NaN        NaN        NaN
# 528            0           0        NaN          NaN        NaN        NaN
# 533            0           0        NaN          NaN        NaN        NaN
# 535            0           0        NaN          NaN        NaN        NaN
# 562            0           0        NaN          NaN        NaN        NaN
# 582            0           0        NaN          NaN        NaN        NaN
# 613            0           0        NaN          NaN        NaN        NaN
# 614            0           0        NaN          NaN        NaN        NaN
# 620            0           0        NaN          NaN        NaN        NaN
# 635            0           0        NaN          NaN        NaN        NaN
# 636            0           0        NaN          NaN        NaN        NaN
# 638            0           0        NaN          NaN        NaN        NaN
# 649            0           0        NaN          NaN        NaN        NaN
# 705            0           0        NaN          NaN        NaN        NaN
# 710            0           0        NaN          NaN        NaN        NaN
# 738            0           0        NaN          NaN        NaN        NaN
# 750            0           0        NaN          NaN        NaN        NaN
# 784            0           0        NaN          NaN        NaN        NaN
# 826            0           0        NaN          NaN        NaN        NaN
# 843            0           0        NaN          NaN        NaN        NaN
# 921            0           0        NaN          NaN        NaN        NaN
# 942            0           0        NaN          NaN        NaN        NaN
# 954            0           0        NaN          NaN        NaN        NaN
# 960            0           0        NaN          NaN        NaN        NaN
# 968            0           0        NaN          NaN        NaN        NaN
# 970            0           0        NaN          NaN        NaN        NaN
# 976            0           0        NaN          NaN        NaN        NaN
# 1009           0           0        NaN          NaN        NaN        NaN
# 1011           0           0        NaN          NaN        NaN        NaN
# 1030           0           0        NaN          NaN        NaN        NaN
# 1038           0           0        NaN          NaN        NaN        NaN
# 1096           0           0        NaN          NaN        NaN        NaN
# 1123           0           0        NaN          NaN        NaN        NaN
# 1131           0           0        NaN          NaN        NaN        NaN
# 1137           0           0        NaN          NaN        NaN        NaN
# 1143           0           0        NaN          NaN        NaN        NaN
# 1173           0           0        NaN          NaN        NaN        NaN
# 1179           0           0        NaN          NaN        NaN        NaN
# 1218           0           0        NaN          NaN        NaN        NaN
# 1219           0           0        NaN          NaN        NaN        NaN
# 1234           0           0        NaN          NaN        NaN        NaN
# 1257           0           0        NaN          NaN        NaN        NaN
# 1283           0           0        NaN          NaN        NaN        NaN
# 1323           0           0        NaN          NaN        NaN        NaN
# 1325           0           0        NaN          NaN        NaN        NaN
# 1326           0           0        NaN          NaN        NaN        NaN
# 1337           0           0        NaN          NaN        NaN        NaN
# 1349           0           0        NaN          NaN        NaN        NaN
# 1407           0           0        NaN          NaN        NaN        NaN
# 1449           0           0        NaN          NaN        NaN        NaN
# 1450           0           0        NaN          NaN        NaN        NaN
# 1453           0           0        NaN          NaN        NaN        NaN
#
#       GarageYrBlt
# 39            NaN
# 48            NaN
# 78            NaN
# 88            NaN
# 89            NaN
# 99            NaN
# 108           NaN
# 125           NaN
# 127           NaN
# 140           NaN
# 148           NaN
# 155           NaN
# 163           NaN
# 165           NaN
# 198           NaN
# 210           NaN
# 241           NaN
# 250           NaN
# 287           NaN
# 291           NaN
# 307           NaN
# 375           NaN
# 386           NaN
# 393           NaN
# 431           NaN
# 434           NaN
# 441           NaN
# 464           NaN
# 495           NaN
# 520           NaN
# 528           NaN
# 533           NaN
# 535           NaN
# 562           NaN
# 582           NaN
# 613           NaN
# 614           NaN
# 620           NaN
# 635           NaN
# 636           NaN
# 638           NaN
# 649           NaN
# 705           NaN
# 710           NaN
# 738           NaN
# 750           NaN
# 784           NaN
# 826           NaN
# 843           NaN
# 921           NaN
# 942           NaN
# 954           NaN
# 960           NaN
# 968           NaN
# 970           NaN
# 976           NaN
# 1009          NaN
# 1011          NaN
# 1030          NaN
# 1038          NaN
# 1096          NaN
# 1123          NaN
# 1131          NaN
# 1137          NaN
# 1143          NaN
# 1173          NaN
# 1179          NaN
# 1218          NaN
# 1219          NaN
# 1234          NaN
# 1257          NaN
# 1283          NaN
# 1323          NaN
# 1325          NaN
# 1326          NaN
# 1337          NaN
# 1349          NaN
# 1407          NaN
# 1449          NaN
# 1450          NaN
# 1453          NaN

# %%
garage_cols = [
    "GarageType",
    "GarageFinish",
    "GarageQual",
    "GarageCond"
]

mask_no_garage = train_data["GarageArea"] == 0

train_data.loc[mask_no_garage, garage_cols] = "NA"
train_data.loc[mask_no_garage, "GarageYrBlt"] = 0

# %%
(
    train_data.isna()
    .sum()
    .loc[lambda x: x > 0]
    .sort_values(ascending=False)
)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## Implementing Second Model (XGBoost)
# ### Since our model is too simple we will be adding more features to it and then we will apply XGBoost as it is considered better in handling high end values

# %%
train_data.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
# 5   6          50       RL         85.0    14115   Pave      IR1         Lvl
# 6   7          20       RL         75.0    10084   Pave      Reg         Lvl
# 7   8          60       RL         81.0    10382   Pave      IR1         Lvl
# 8   9          50       RM         51.0     6120   Pave      Reg         Lvl
# 9  10         190       RL         50.0     7420   Pave      Reg         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
# 5    AllPub    Inside       Gtl      Mitchel       Norm       Norm     1Fam
# 6    AllPub    Inside       Gtl      Somerst       Norm       Norm     1Fam
# 7    AllPub    Corner       Gtl       NWAmes       PosN       Norm     1Fam
# 8    AllPub    Inside       Gtl      OldTown     Artery       Norm     1Fam
# 9    AllPub    Corner       Gtl      BrkSide     Artery     Artery   2fmCon
#
#   HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 0     2Story            7            5       2003          2003     Gable
# 1     1Story            6            8       1976          1976     Gable
# 2     2Story            7            5       2001          2002     Gable
# 3     2Story            7            5       1915          1970     Gable
# 4     2Story            8            5       2000          2000     Gable
# 5     1.5Fin            5            5       1993          1995     Gable
# 6     1Story            8            5       2004          2005     Gable
# 7     2Story            7            6       1973          1973     Gable
# 8     1.5Fin            7            5       1931          1950     Gable
# 9     1.5Unf            5            6       1939          1950     Gable
#
#   RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond  \
# 0  CompShg     VinylSd     VinylSd    BrkFace       196.0        Gd        TA
# 1  CompShg     MetalSd     MetalSd         NA         0.0        TA        TA
# 2  CompShg     VinylSd     VinylSd    BrkFace       162.0        Gd        TA
# 3  CompShg     Wd Sdng     Wd Shng         NA         0.0        TA        TA
# 4  CompShg     VinylSd     VinylSd    BrkFace       350.0        Gd        TA
# 5  CompShg     VinylSd     VinylSd         NA         0.0        TA        TA
# 6  CompShg     VinylSd     VinylSd      Stone       186.0        Gd        TA
# 7  CompShg     HdBoard     HdBoard      Stone       240.0        TA        TA
# 8  CompShg     BrkFace     Wd Shng         NA         0.0        TA        TA
# 9  CompShg     MetalSd     MetalSd         NA         0.0        TA        TA
#
#   Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1  \
# 0      PConc       Gd       TA           No          GLQ         706
# 1     CBlock       Gd       TA           Gd          ALQ         978
# 2      PConc       Gd       TA           Mn          GLQ         486
# 3     BrkTil       TA       Gd           No          ALQ         216
# 4      PConc       Gd       TA           Av          GLQ         655
# 5       Wood       Gd       TA           No          GLQ         732
# 6      PConc       Ex       TA           Av          GLQ        1369
# 7     CBlock       Gd       TA           Mn          ALQ         859
# 8     BrkTil       TA       TA           No          Unf           0
# 9     BrkTil       TA       TA           No          GLQ         851
#
#   BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC  \
# 0          Unf           0        150          856    GasA        Ex
# 1          Unf           0        284         1262    GasA        Ex
# 2          Unf           0        434          920    GasA        Ex
# 3          Unf           0        540          756    GasA        Gd
# 4          Unf           0        490         1145    GasA        Ex
# 5          Unf           0         64          796    GasA        Ex
# 6          Unf           0        317         1686    GasA        Ex
# 7          BLQ          32        216         1107    GasA        Ex
# 8          Unf           0        952          952    GasA        Gd
# 9          Unf           0        140          991    GasA        Ex
#
#   CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  \
# 0          Y      SBrkr       856       854             0       1710
# 1          Y      SBrkr      1262         0             0       1262
# 2          Y      SBrkr       920       866             0       1786
# 3          Y      SBrkr       961       756             0       1717
# 4          Y      SBrkr      1145      1053             0       2198
# 5          Y      SBrkr       796       566             0       1362
# 6          Y      SBrkr      1694         0             0       1694
# 7          Y      SBrkr      1107       983             0       2090
# 8          Y      FuseF      1022       752             0       1774
# 9          Y      SBrkr      1077         0             0       1077
#
#    BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 0             1             0         2         1             3             1
# 1             0             1         2         0             3             1
# 2             1             0         2         1             3             1
# 3             1             0         1         0             3             1
# 4             1             0         2         1             4             1
# 5             1             0         1         1             1             1
# 6             1             0         2         0             3             1
# 7             1             0         2         1             3             1
# 8             0             0         2         0             2             2
# 9             1             0         1         0             2             2
#
#   KitchenQual  TotRmsAbvGrd Functional  Fireplaces GarageType  GarageYrBlt  \
# 0          Gd             8        Typ           0     Attchd       2003.0
# 1          TA             6        Typ           1     Attchd       1976.0
# 2          Gd             6        Typ           1     Attchd       2001.0
# 3          Gd             7        Typ           1     Detchd       1998.0
# 4          Gd             9        Typ           1     Attchd       2000.0
# 5          TA             5        Typ           0     Attchd       1993.0
# 6          Gd             7        Typ           1     Attchd       2004.0
# 7          TA             7        Typ           2     Attchd       1973.0
# 8          TA             8       Min1           2     Detchd       1931.0
# 9          TA             5        Typ           2     Attchd       1939.0
#
#   GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0          RFn           2         548         TA         TA          Y
# 1          RFn           2         460         TA         TA          Y
# 2          RFn           2         608         TA         TA          Y
# 3          Unf           3         642         TA         TA          Y
# 4          RFn           3         836         TA         TA          Y
# 5          Unf           2         480         TA         TA          Y
# 6          RFn           2         636         TA         TA          Y
# 7          RFn           2         484         TA         TA          Y
# 8          Unf           2         468         Fa         TA          Y
# 9          RFn           1         205         Gd         TA          Y
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# 0           0           61              0          0            0         0
# 1         298            0              0          0            0         0
# 2           0           42              0          0            0         0
# 3           0           35            272          0            0         0
# 4         192           84              0          0            0         0
# 5          40           30              0        320            0         0
# 6         255           57              0          0            0         0
# 7         235          204            228          0            0         0
# 8          90            0            205          0            0         0
# 9           0            4              0          0            0         0
#
#    MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice  SalePrice_log
# 0        0       2    2008       WD        Normal     208500      12.247699
# 1        0       5    2007       WD        Normal     181500      12.109016
# 2        0       9    2008       WD        Normal     223500      12.317171
# 3        0       2    2006       WD       Abnorml     140000      11.849405
# 4        0      12    2008       WD        Normal     250000      12.429220
# 5      700      10    2009       WD        Normal     143000      11.870607
# 6        0       8    2007       WD        Normal     307000      12.634606
# 7      350      11    2009       WD        Normal     200000      12.206078
# 8        0       4    2008       WD       Abnorml     129900      11.774528
# 9        0       1    2008       WD        Normal     118000      11.678448

# %%
import matplotlib.pyplot as plt
import math

TARGET = "SalePrice"
MAX_CATEGORIES = 30      # more realistic for Ames
PLOTS_PER_ROW = 3
FIG_WIDTH = 18
ROW_HEIGHT = 4

# Select categorical columns safely
cat_cols = train_data.select_dtypes(
    include=["object", "string", "category"]
).columns.tolist()


# Filter only extremely high-cardinality features
cat_cols = [
    col for col in cat_cols
    if train_data[col].nunique() <= MAX_CATEGORIES
]

# -----------------------------
# SAFETY CHECK
# -----------------------------
if len(cat_cols) == 0:
    raise ValueError(
        "No categorical columns selected. "
        "Increase MAX_CATEGORIES or inspect your data."
    )

n_plots = len(cat_cols)
n_rows = math.ceil(n_plots / PLOTS_PER_ROW)

fig, axes = plt.subplots(
    n_rows,
    PLOTS_PER_ROW,
    figsize=(FIG_WIDTH, ROW_HEIGHT * n_rows),
    squeeze=False
)

for i, col in enumerate(cat_cols):
    r, c = divmod(i, PLOTS_PER_ROW)
    ax = axes[r, c]

    train_data.boxplot(
        column=TARGET,
        by=col,
        ax=ax
    )

    ax.set_title(col, fontsize=10)
    ax.set_xlabel("")
    ax.set_ylabel("")

# Remove unused axes
for j in range(i + 1, n_rows * PLOTS_PER_ROW):
    r, c = divmod(j, PLOTS_PER_ROW)
    fig.delaxes(axes[r][c])

plt.suptitle("")
plt.tight_layout()
plt.show()
